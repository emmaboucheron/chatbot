# %% [markdown]
# <center>
# <a href="http://www.insa-toulouse.fr/" ><img src="http://www.math.univ-toulouse.fr/~besse/Wikistat/Images/logo-insa.jpg" style="float:left; max-width: 120px; display: inline" alt="INSA"/></a>
#
# <a href="http://wikistat.fr/" ><img src="http://www.math.univ-toulouse.fr/~besse/Wikistat/Images/wikistat.jpg" style="max-width: 250px; display: inline"  alt="Wikistat"/></a>
#
# <a href="http://www.math.univ-toulouse.fr/" ><img src="http://www.math.univ-toulouse.fr/~besse/Wikistat/Images/logo_imt.jpg" style="float:right; max-width: 250px; display: inline" alt="IMT"/> </a>
# </center>

# %% [markdown]
# # [Ateliers: Technologies des données massives](https://github.com/wikistat/Ateliers-Big-Data)

# %% [markdown]
# # Text Mining et Catégorisation de Produits en <a href="https://www.python.org/"><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Python_logo_and_wordmark.svg/390px-Python_logo_and_wordmark.svg.png" style="max-width: 120px; display: inline" alt="R"/></a> avec <a href="http://scikit-learn.org/stable/#"><img src="http://scikit-learn.org/stable/_static/scikit-learn-logo-small.png" style="max-width: 100px; display: inline" alt="R"/></a>

# %% [markdown]
# ## Introduction

# %% [markdown]
# Il s'agit d'une version simplifiée du concours proposé par CDiscount et paru sur le site [datascience.net](https://www.datascience.net/fr/challenge). Les données d'apprentissage sont accessibles sur demande auprès de CDiscount. Les solutions de l'échantillon test du concours ne sont pas et ne seront pas rendues publiques. Un échantillon test est donc construit pour l'usage de ce tutoriel.  L'objectif est de prévoir la catégorie d'un produit à partir de son descriptif. Seule la catégorie principale (1er niveau) est prédite au lieu des trois niveaux demandés dans le concours. L'objectif est plutôt de comparer les performances des méthodes et technologies en fonction de la taille de la base d'apprentissage ainsi que d'illustrer sur un exemple complexe le prétraitement de données textuelles. La stratégie de sous ou sur échantillonnage des catégories qui permet d'améliorer la prévision n'a pas été mise en oeuvre.
# * L'exemple est présenté sur un échantillon réduit d'un million de produits au lieu des 15M initiaux
# * L'échantillon réduit peut encore l'être puis séparé en 2 parties: apprentissage et validation.
# * Les données textuelles sont  nettoyées, racinisées, vectorisées avant modélisation.
# * Trois modélisations sont estimées: logistique, arbre, forêt aléatoire.
# * Optimiser l'erreur en faisant varier différents paramètres: types et paramètres de vectorisation (TF-IDF), paramètres de la régression logistique (pénalisation l1) et de la forêt aléatoire (nombre d'arbres et nombre de variables aléatoire).
#
# Exécuter finalement le code pour différentes tailles (paramètre  `tauxTot` ci-dessous) de l'échantillon d'apprentissage et comparer les qualités de prévision obtenues.
#
# Deux échantillons de test ont été mis de côté et seront utilisés dans un prochain calepin (avec pyspark) pour comparer les stratégies.

# %%
#Importation des librairies utilisées
import unicodedata 
import time
import pandas as pd
import numpy as np
import random
import nltk
import collections
import itertools
import csv
import warnings

from sklearn.cross_validation import train_test_split
# Out:
# C:\Users\ETIENNE\Anaconda2\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.decomposition import TruncatedSVD
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Importation des données
# Définition du répertoir de travail, des noms des différents fichiers utilisés et des variables globales.
#
# Dans un premier temps, il vous faut télécharger les fichiers `Categorie_reduit.csv` et `lucene_stopwords.txt` disponible dans le corpus de données de [wikistat](http://wikistat.fr/).
#
# Une fois téléchargées, placez ces données dans le repertoire de travail de votre choix et préciser la direction de ce repertoir dans la variable `DATA_DIR`

# %%
# Répertoire de travail
DATA_DIR = "C:/Users/ETIENNE/Documents/Work/INSA/4A/Projets 4gmm 2018/"

# Nom des fichiers
training_reduit_path = DATA_DIR + "INSA_wefight_data_clean.csv"
# Variable Globale
HEADER_TEST = ['Question','Intent','BlockId', 'Action']
HEADER_TRAIN =['Question','Intent','BlockId', 'Action']

# %%
## Si nécessaire (première exécution) chargement de nltk, librairie pour la suppression 
## des mots d'arrêt et la racinisation
## nltk.download()

# %% [markdown]
#    ### Read & Split Dataset
#    Fonction permettant de lire le fichier d'apprentissage et de créer deux DataFrame Pandas, un pour l'apprentissage, l'autre pour la validation.
#    La première méthode créée un DataFrame en lisant entièrement le fichier. Puis elle scinde le DataFrame en deux  grâce à la fonction dédiée de sklearn.

# %%
def split_dataset(input_path, nb_line, tauxValid,columns):
    time_start = time.time()
    data_all = pd.read_csv(input_path,sep=",",names=columns,nrows=nb_line) #cree data frame
    data_all = data_all.fillna("") #remplace les na par " "
    data_train, data_valid = train_test_split(data_all, test_size = tauxValid) # Split arrays or matrices into random train and test subsets
    time_end = time.time()
    print("Split Takes %d s" %(time_end-time_start))
    return data_train, data_valid

nb_line=20000  # part totale extraite du fichier initial ici déjà réduit
tauxValid=0.10 # part totale extraite du fichier initial ici déjà réduit
data_train, data_valid = split_dataset(training_reduit_path, nb_line, tauxValid, HEADER_TRAIN)
# Cette ligne permet de visualiser les 5 premières lignes de la DataFrame 
data_train.head(5)
# Out:
# Split Takes 0 s
#                                                Question  \
# 2658  est-ce que les traitement anti hormono entrain...
# 2135  Nous  avons reçu  des feuilles  à signer  pour...
# 2393                      comment agit la radiothérapie
# 465                    troubles sexuels après un cancer
# 4618                  Témoignage cancer avec metastases
#
#                                              Intent                   BlockId  \
# 2658  #6-31_TRTEINS_Effetsecondaireshormonotherapie  59632c41e4b0a226d067cee4
# 2135                #2-96_QVDP_Social_Priseencharge  598b43bee4b03f0d36d5f410
# 2393                    #6-18_TRTEINS_Radiotherapie  59632c41e4b0a226d067cc75
# 465                           #2-120_QVDP_Sexualite  599188f4e4b0feb288676fca
# 4618                   #9-13_Informations_metastase  59632c41e4b0a226d067ca41
#
#            Action
# 2658  wiki_cancer
# 2135  wiki_cancer
# 2393  wiki_cancer
# 465   wiki_cancer
# 4618  wiki_cancer

# %% [markdown]
# ## 2. Nettoyage des données
# Afin de limiter la dimension de l'espace des variables ou *features*, tout en conservant les informations essentielles, il est nécessaire de nettoyer les données en appliquant plusieurs étapes:
# * Chaque mot est écrit en minuscule.
# * Les termes numériques, de ponctuation et autres symboles sont supprimés.
# * 155 mots-courants, et donc non informatifs, de la langue française sont supprimés (STOPWORDS). Ex: le, la, du, alors, etc...
# * Chaque mot est "racinisé", via la fonction `STEMMER.stem` de la librairie nltk. La racinisation transforme un mot en son radical ou sa racine. Par exemple, les mots: cheval, chevaux, chevalier, chevalerie, chevaucher sont tous remplacés par "cheva".

# %% [markdown]
# ### Importation des librairies et fichier pour le nettoyage des données.

# %%
# Librairies 
from bs4 import BeautifulSoup #Nettoyage d'HTML
import re # Regex
import nltk # Nettoyage des données

## listes de mots à supprimer dans la description des produits
## Depuis NLTK
nltk_stopwords = nltk.corpus.stopwords.words('french') 
## Depuis Un fichier externe.
lucene_stopwords = [unicode(w, "utf-8") for w in open(DATA_DIR+"lucene_stopwords.txt").read().split(",")] #En local

## Union des deux fichiers de stopwords 
stopwords = list(set(nltk_stopwords).union(set(lucene_stopwords)))

## Fonction de setmming de stemming permettant la racinisation
stemmer=nltk.stem.SnowballStemmer('french')

# %% [markdown]
# ### Fonction de nettoyage de texte
# Fonction qui prend en intrée un texte et retourne le texte nettoyé en appliquant successivement les étapes suivantes: Nettoyage des données HTML, conversion en texte minuscule, encodage uniforme, suppression des caractéres non alpha numérique (ponctuations), suppression des stopwords, racinisation de chaque mot individuellement.

# %%
# remarque
#'a b c'.split()
#str.split('a b c')
# both return ['a', 'b', 'c']

# %%
# Fonction clean générale
def clean_txt(txt):
    ### remove html stuff
    txt = BeautifulSoup(txt,"html.parser",from_encoding='utf-8').get_text() #nettoyage donnee html
    ### lower case
    txt = txt.lower()
    ### special escaping character '...'
    txt = txt.replace(u'\u2026','.')
    txt = txt.replace(u'\u00a0',' ')
    ### remove accent btw
    txt = unicodedata.normalize('NFD', txt).encode('ascii', 'ignore')
    ###txt = unidecode(txt)
    ### remove non alphanumeric char
    txt = re.sub('[^a-z_]', ' ', txt)
    ### remove french stop words
    tokens = [w for w in txt.split() if (len(w)>2) and (w not in stopwords)]
    ### french stemming
    tokens = [stemmer.stem(token) for token in tokens]
    #Stemmers remove morphological affixes from words, leaving only the word stem
    ### tokens = stemmer.stemWords(tokens)
    return ' '.join(tokens)
    #join() returns a string in which the string elements of sequence have been joined by str separator.

def clean_marque(txt):
    txt = re.sub('[^a-zA-Z0-9]', '_', txt).lower()
    return txt

# %% [markdown]
# ### Nettoyage des DataFrames
# Applique le nettoyage sur toutes les lignes de la DataFrame

# %%
# fonction de nettoyage du fichier(stemming et liste de mots à supprimer)
def clean_df(input_data, column_names= ['Question','Intent','BlockId', 'Action']):
    #Test if columns entry match columns names of input data
    column_names_diff= set(column_names).difference(set(input_data.columns))
    #set.difference   new set with elements in column_names but not in input_data.columns
    
    if column_names_diff: #rentre dans la boucle si column_names différent zero
        # warning = exception
        warnings.warn("Column(s) '"+", ".join(list(column_names_diff)) +"' do(es) not match columns of input data", Warning)
        
    nb_line = input_data.shape[0]
    print("Start Clean %d lines" %nb_line)
    
    # Cleaning start for each columns
    time_start = time.time()
    clean_list=[]
    for column_name in column_names:
        column = input_data[column_name].values
        if column_name == "Question":
            array_clean = np.array(map(clean_txt,column))
            
        elif column_name == "Intent":
            array_clean = np.asarray(input_data['Intent']) #on recopie telle quelle la colonne intent  
            
        else:
            array_clean = np.array(map(clean_marque,column))
            #applies a function to all the items in an input_list
            #map(function_to_apply, list_of_inputs)
        clean_list.append(array_clean)
    time_end = time.time()
    print("Cleaning time: %d secondes"%(time_end-time_start))
    
    #Convert list to DataFrame
    array_clean = np.array(clean_list).T
    data_clean = pd.DataFrame(array_clean, columns = column_names)
    return data_clean

# %%
# Take approximately 2 minutes fors 100.000 rows
data_valid_clean = clean_df(data_valid)
data_train_clean = clean_df(data_train)
# Out:
# Start Clean 502 lines
# Cleaning time: 0 secondes
# Start Clean 4511 lines
# Cleaning time: 6 secondes

# %% [markdown]
# Affiche les 5 premières lignes de la DataFrame d'apprentissage après nettoyage.

# %%
#info sur les données
data_train_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4511 entries, 0 to 4510
# Data columns (total 4 columns):
# Question    4511 non-null object
# Intent      4511 non-null object
# BlockId     4511 non-null object
# Action      4511 non-null object
# dtypes: object(4)
# memory usage: 141.0+ KB

# %%
data_train_clean
# Out:
#                                                Question  \
# 0                  trait anti hormono entrain pris poid
# 1     recu feuill sign accord comiss docteur dossi m...
# 2                                      agit radiotherap
# 3                               troubl sexuel apre canc
# 4                               temoignag canc metastas
# 5                                     different manchon
# 6                                            radioterap
# 7                                         trait diarrhe
# 8                                     curcum anticancer
# 9                                        remed peau pel
# 10                                             vivr mar
# 11          fait reconstruct pos prothes veux savoir vi
# 12                                   sert homornotherap
# 13                                    typ perruqu chois
# 14                                   limit pert cheveux
# 15                                       rayon radioact
# 16                                       chaleur hormon
# 17                           cathet precaut dois prendr
# 18                                        grad iii grav
# 19                                        achet perruqu
# 20                                          rest fertil
# 21                                     risqu infect pac
# 22                               prothes capillair canc
# 23                                      peux fair siest
# 24                                  deven mer apre canc
# 25                                         pac fait mal
# 26                                     maigr apre trait
# 27                                     es_alopecie_chev
# 28                                        bouff chaleur
# 29                                       partenair envi
# ...                                                 ...
# 4481                           therap hormonal grossess
# 4482                                   syndrom yeux sec
# 4483                                   beaucoup douleur
# 4484                                             anorex
# 4485                                           font mal
# 4486                                       langu blanch
# 4487                                      don sein canc
# 4488                                       allait rryon
# 4489                                  secheress vaginal
# 4490                                       peux aid stp
# 4491                                          aim sport
# 4492                                            sourcil
# 4493                                          peut mang
# 4494                                   inform personnel
# 4495                                vom apre pris medic
# 4496                              achet prothes mammair
# 4497                                          march had
# 4498                            fair mal rapport sexuel
# 4499                           radiotherap normal froid
# 4500                                            enceint
# 4501              veut dir veut dir stad stad stad stad
# 4502                        allaitementgest mauv enfant
# 4503                         kin fair pressotherap cest
# 4504                            fair seanc pressotherap
# 4505                                  prothes capillair
# 4506                                    drainag lymphat
# 4507                                   pert poid import
# 4508                                puis mang grain lin
# 4509                                      preven ballon
# 4510                       peux utilis fer fris perruqu
#
#                                              Intent                   BlockId  \
# 0     #6-31_TRTEINS_Effetsecondaireshormonotherapie  59632c41e4b0a226d067cee4
# 1                   #2-96_QVDP_Social_Priseencharge  598b43bee4b03f0d36d5f410
# 2                       #6-18_TRTEINS_Radiotherapie  59632c41e4b0a226d067cc75
# 3                             #2-120_QVDP_Sexualite  599188f4e4b0feb288676fca
# 4                      #9-13_Informations_metastase  59632c41e4b0a226d067ca41
# 5                   #6-41_TRTEINS_ManchonLymphodeme  598b5110e4b03f0d3718d13f
# 6                       #6-18_TRTEINS_Radiotherapie  59632c41e4b0a226d067cc75
# 7                            #6-92_TRTEINS_Diarrhee  5993f1d6e4b068eebe2bac82
# 8                          #2-130_QVDP_Alimentation  5991c543e4b0b2045b0c568f
# 9                                #6-49_TRTEINS_Peau  59918cf1e4b0feb28881fd9f
# 10                            #2-120_QVDP_Sexualite  599188f4e4b0feb288676fca
# 11             #2-125_QVDP_Sexualite_Reconstruction  59918ad1e4b0feb288736b42
# 12                    #6-24_TRTEINS_hormonotherapie  59632c41e4b0a226d067cc6d
# 13                    #2-102_QVDP_Social_RbPerruque  598b44bbe4b03f0d36db5303
# 14                     #2-41_QVDP_Alopecie_Diminuer  59843588e4b03f0d12d83b08
# 15                      #6-18_TRTEINS_Radiotherapie  59632c41e4b0a226d067cc75
# 16    #6-31_TRTEINS_Effetsecondaireshormonotherapie  59632c41e4b0a226d067cee4
# 17                    #6-63_TRTEINS_PAC_Precautions  59919312e4b0feb288ab0b47
# 18                        #9-20_Informations_Stades  59632c41e4b0a226d067ca61
# 19                   #2-49_QVDP_Alopecie_OuPerruque  598439eae4b03f0d12f637ea
# 20                   #2-85_QVDP_Fertilite_Preserver  598b4097e4b03f0d36c59dc2
# 21                        #6-64_TRTEINS_PAC_Risques  5991933de4b0feb288ac2399
# 22                     #2-45_QVDP_Alopecie_Perruque  5984386ee4b03f0d12ec6c33
# 23                        #2-72_QVDP_Fatigue_Sieste  59846316e4b03f0d141962b2
# 24        #2-84_QVDP_Fertilite_GrossesseApresCancer  598b402ce4b03f0d36c34a40
# 25                        #6-64_TRTEINS_PAC_Risques  5991933de4b0feb288ac2399
# 26                        #6-96_TRTEINS_Perte_Poids  5993f2cae4b068eebe3131e2
# 27                     #2-36_QVDP_Alopecie_Pourquoi  5984243ae4b03f0d12766ac7
# 28    #6-31_TRTEINS_Effetsecondaireshormonotherapie  59632c41e4b0a226d067cee4
# 29                     #2-128_QVDP_Sexualite_Couple  59918bd4e4b0feb2887a1c56
# ...                                             ...                       ...
# 4481          #2-112_QVDP_Grossesse_Hormonotherapie  598d6ef6e4b03f0d40bdf494
# 4482                        #6-57_TRTEINS_Yeux_Secs  59918e4de4b0feb2888bc59e
# 4483                             #2-55_QVDP_Douleur  59843bb8e4b03f0d1304835d
# 4484                      #6-96_TRTEINS_Perte_Poids  5993f2cae4b068eebe3131e2
# 4485                             #2-55_QVDP_Douleur  59843bb8e4b03f0d1304835d
# 4486                     #6-58_TRTEINS_Bouche_Seche  59918e6ee4b0feb2888c9bcd
# 4487              #2-115_QVDP_Grossesse_Allaitement  598d6f5fe4b03f0d40c062d3
# 4488              #2-115_QVDP_Grossesse_Allaitement  598d6f5fe4b03f0d40c062d3
# 4489                             #6-49_TRTEINS_Peau  59918cf1e4b0feb28881fd9f
# 4490                    #5-37_Soutien_Psychologique  59632c41e4b0a226d067c7ba
# 4491                               #2-73_QVDP_Sport  59895c38e4b03f0d2cd9a559
# 4492                                #2-53_QVDP_Cils  59843b3ce4b03f0d13005d53
# 4493                       #2-130_QVDP_Alimentation  5991c543e4b0b2045b0c568f
# 4494                                   Profile_read  596340c2e4b0a226d0f5360a
# 4495             #6-97_TRTEINS_Nausees_Vomissements  59955d76e4b032e0e7890bdf
# 4496                         #6-83_TRTEINS_Prothese  59919701e4b0feb288c56a79
# 4497                         #2-106_QVDP_Social_HAD  598b4541e4b03f0d36de29d9
# 4498                          #2-120_QVDP_Sexualite  599188f4e4b0feb288676fca
# 4499                          #2-58_QVDP_RadioT_Eff  59843d91e4b03f0d13119537
# 4500                          #2-107_QVDP_Grossesse  598d6de3e4b03f0d40b7891f
# 4501                      #9-20_Informations_Stades  59632c41e4b0a226d067ca61
# 4502              #2-115_QVDP_Grossesse_Allaitement  598d6f5fe4b03f0d40c062d3
# 4503         #6-40_TRTEINS_PressotherapieLymphodeme  598b50f2e4b03f0d37184ae0
# 4504         #6-40_TRTEINS_PressotherapieLymphodeme  598b50f2e4b03f0d37184ae0
# 4505                   #2-45_QVDP_Alopecie_Perruque  5984386ee4b03f0d12ec6c33
# 4506               #6-39_TRTEINS_DrainageLymphodeme  598b50d6e4b03f0d3717ad2d
# 4507                      #6-96_TRTEINS_Perte_Poids  5993f2cae4b068eebe3131e2
# 4508                       #2-130_QVDP_Alimentation  5991c543e4b0b2045b0c568f
# 4509                     #6-91_TRTEINS_Ballonnement  5993f166e4b068eebe293b35
# 4510                   #2-45_QVDP_Alopecie_Perruque  5984386ee4b03f0d12ec6c33
#
#                              Action
# 0                       wiki_cancer
# 1                       wiki_cancer
# 2                       wiki_cancer
# 3                       wiki_cancer
# 4                       wiki_cancer
# 5                       wiki_cancer
# 6                       wiki_cancer
# 7                       wiki_cancer
# 8                       wiki_cancer
# 9                       wiki_cancer
# 10                      wiki_cancer
# 11                      wiki_cancer
# 12                      wiki_cancer
# 13                      wiki_cancer
# 14                      wiki_cancer
# 15                      wiki_cancer
# 16                      wiki_cancer
# 17                      wiki_cancer
# 18                      wiki_cancer
# 19                      wiki_cancer
# 20                      wiki_cancer
# 21                      wiki_cancer
# 22                      wiki_cancer
# 23                      wiki_cancer
# 24                      wiki_cancer
# 25                      wiki_cancer
# 26                      wiki_cancer
# 27                      wiki_cancer
# 28                      wiki_cancer
# 29
# ...                             ...
# 4481                    wiki_cancer
# 4482                    wiki_cancer
# 4483                    wiki_cancer
# 4484                    wiki_cancer
# 4485                    wiki_cancer
# 4486                    wiki_cancer
# 4487                    wiki_cancer
# 4488                    wiki_cancer
# 4489                    wiki_cancer
# 4490                    wiki_cancer
# 4491                    wiki_cancer
# 4492                    wiki_cancer
# 4493                    wiki_cancer
# 4494  conversation_fichepatientread
# 4495                    wiki_cancer
# 4496                    wiki_cancer
# 4497                    wiki_cancer
# 4498                    wiki_cancer
# 4499                    wiki_cancer
# 4500                    wiki_cancer
# 4501                    wiki_cancer
# 4502                    wiki_cancer
# 4503                    wiki_cancer
# 4504                    wiki_cancer
# 4505                    wiki_cancer
# 4506                    wiki_cancer
# 4507                    wiki_cancer
# 4508                    wiki_cancer
# 4509                    wiki_cancer
# 4510                    wiki_cancer
#
# [4511 rows x 4 columns]

# %%
#description des données
data_train_clean.describe()
# Out:
#        Question              Intent                   BlockId       Action
# count      4511                4511                      4511         4511
# unique     3802                 146                       133           21
# top        rend  #6-49_TRTEINS_Peau  59918cf1e4b0feb28881fd9f  wiki_cancer
# freq         17                 190                       190         4241

# %%
# comptage u nbre d'occurence de categorie puis comptage du nbre de categorie differente
print(data_train["Action"].value_counts())
print("nb Action differente",(data_train["Action"].value_counts()).shape)
# Out:
# wiki_cancer                                          4241
#                                                        87
# conversation_rappelRendezVous                          77
# conversation_rappelRead                                34
# conversation_rappelUpdate2                             17
# wiki_cancer#                                           13
# conversation_FichePatientRead                          11
# conversation_hist                                       6
# conversation_FichePatientUpdate                         6
# conversation_FichePatientWrite:doseTraitement           4
# conversation_FichePatientWrite:newsletter               2
# conversation_FichePatientWrite:typeTraitement           2
# conversation_rappelUpdate                               2
# conversation_FichePatientWrite:age                      2
# conversation_FichePatientWrite:rappels                  1
# conversation_FichePatientWrite:partagerTemoignage       1
# conversation_FichePatientWrite:recevoirTemoignage       1
# conversation_FichePatientWrite:nomTraitement            1
# conversation_FichePatientWrite:role                     1
# conversation_FichePatientWrite:cancerType               1
# action                                                  1
# Name: Action, dtype: int64
# ('nb Action differente', (21L,))

# %%
# comptage u nbre d'occurence de categorie puis comptage du nbre de categorie differente
print(data_train["Intent"].value_counts())
print("nb intent differente",(data_train["Intent"].value_counts()).shape)
# Out:
# #6-49_TRTEINS_Peau                               190
# #6-97_TRTEINS_Nausees_Vomissements               122
# #6-92_TRTEINS_Diarrhee                           120
# #2-130_QVDP_Alimentation                         115
# #6-53_TRTEINS_Aphtes                             109
# #6-90_TRTEINS_Mauvais_Gout                       105
# #6-98_TRTEINS_EI_Frequents                       104
# #2-36_QVDP_Alopecie_Pourquoi                     101
# #6-60_TRTEINS_PAC                                 94
# #9-2_Informations_cancer                          93
# #6-57_TRTEINS_Yeux_Secs                           87
# #2-64-0_QVDP_Fatigue                              86
# #6-18_TRTEINS_Radiotherapie                       85
# #6-96_TRTEINS_Perte_Poids                         80
# #2-55_QVDP_Douleur                                79
# conversation_rappel_rendezvous                    77
# #6-1_TRTEINS_Chimiotherapie                       75
# #2-45_QVDP_Alopecie_Perruque                      75
# #2-96_QVDP_Social_Priseencharge                   67
# #6-58_TRTEINS_Bouche_Seche                        66
# #6-24_TRTEINS_hormonotherapie                     65
# #2-120_QVDP_Sexualite                             63
# #2-107_QVDP_Grossesse                             58
# #2-125_QVDP_Sexualite_Reconstruction              52
# #2-128_QVDP_Sexualite_Couple                      52
# #6-34_TRTEINS_Lymphoedeme                         52
# #6-73_TRTEINS_Chirurgie_Mastectomie               51
# #2-41_QVDP_Alopecie_Diminuer                      49
# #5-37_Soutien_Psychologique                       48
# #6-31_TRTEINS_Effetsecondaireshormonotherapie     47
#                                                 ...
# #6-44_TRTEINS_AllergieManchon                      8
# #8-6_DDP_Consentement_eclaire                      8
# #1-4_Menu_Patient_Recent                           8
# #9-53_Depistage_cancer_sein                        8
# #6-81_TRTEINS_Chirurgie_Mastectomie_risques        7
# #8-9_DDP_Charte_patient                            7
# #6-35_TRTEINS_PrevenirLymphoedeme                  7
# #2-88_QVDP_Fertilite_Cycles                        6
# Conversation_Historique                            6
# Profile_update                                     6
# #2-88_Reprise_Cycle                                6
# #8-13_DDP_Secret_medical                           5
# #7-60_QVDA_Soins_Palliatifs                        5
# #6-5_TRTEINS_ChimioInjectable                      4
# Profile_write_doseTraitement                       4
# #6-68_TRTEINS_Chirurgie_Anesthesie                 4
# #8-11_DDP_Dossier_medical                          4
# #6-47_TRTEINS_InfectionManchon                     3
# Profile_write_newsletter                           2
# Profile_write_age                                  2
# Profile_write_typeTraitement                       2
# Conversation_rappel_update                         2
# intent                                             1
# Profile_write_nomTraitement                        1
# Profile_write_partagerTemoignage                   1
# Profile_write_typeCancer                           1
# Profile_write_role                                 1
# Profile_write_recevoirTemoignage                   1
# #001_Abonnement                                    1
# Profile_write_rappels                              1
# Name: Intent, Length: 146, dtype: int64
# ('nb intent differente', (146L,))

# %%
#on enregistre le contenu de la colonne Question dans un fichier csv
#on fait ensuite un wordcloud sur toutes les donnees
description = data_train_clean["Question"]
description.to_csv('Question.csv', sep = ',')

# %%
from os import path
from wordcloud import WordCloud

#d = path.dirname()

# Read the whole text.
#text = open(path.join(d, 'constitution.txt')).read()
text = open(path.join(DATA_DIR, 'Question.csv')).read()
# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:
#import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# The pil way (if you don't have matplotlib)
# image = wordcloud.to_image()
# image.show()

# %%
# tri par catégorie, on a un data frame pour une catégorie
df = data_train_clean[data_train_clean['Intent'] == '#6-49_TRTEINS_Peau']
df
# Out:
#                                                Question              Intent  \
# 9                                        remed peau pel  #6-49_TRTEINS_Peau
# 39                                      trait peau sech  #6-49_TRTEINS_Peau
# 43       puis hydrat mieux peau visag marqu ply egficac  #6-49_TRTEINS_Peau
# 66                                     retrouv bel peau  #6-49_TRTEINS_Peau
# 82                                evit secheress cutane  #6-49_TRTEINS_Peau
# 88     hello souffr beaucoup brulur scan crem fait rien  #6-49_TRTEINS_Peau
# 92                                      crem dermatolog  #6-49_TRTEINS_Peau
# 95                                         conseil peau  #6-49_TRTEINS_Peau
# 109                                      soin peau tern  #6-49_TRTEINS_Peau
# 149   pens crem dexeryl reuss bien secheress peau pe...  #6-49_TRTEINS_Peau
# 152                                          plaqu roug  #6-49_TRTEINS_Peau
# 174                                            peau sec  #6-49_TRTEINS_Peau
# 205                                           peau sech  #6-49_TRTEINS_Peau
# 210                                          peau bouch  #6-49_TRTEINS_Peau
# 251                                    prendr soin peau  #6-49_TRTEINS_Peau
# 261                                           maquillag  #6-49_TRTEINS_Peau
# 264                                               gratt  #6-49_TRTEINS_Peau
# 283              produit cosmet hydrat perm appliqu cas  #6-49_TRTEINS_Peau
# 284                                      tach roug sein  #6-49_TRTEINS_Peau
# 292                                               gratt  #6-49_TRTEINS_Peau
# 344                              peau sech chimiotherap  #6-49_TRTEINS_Peau
# 352                                      trait peau pel  #6-49_TRTEINS_Peau
# 398                                   peau chimiotherap  #6-49_TRTEINS_Peau
# 440                                          crem apais  #6-49_TRTEINS_Peau
# 450                                         savon neutr  #6-49_TRTEINS_Peau
# 484                                           soin peau  #6-49_TRTEINS_Peau
# 491                                        peau sensibl  #6-49_TRTEINS_Peau
# 508                                  conseil dermatolog  #6-49_TRTEINS_Peau
# 668                                             rougeur  #6-49_TRTEINS_Peau
# 673   jour apre deuxiem chimio plaqu roug apparu bus...  #6-49_TRTEINS_Peau
# ...                                                 ...                 ...
# 3704                                        peau chimio  #6-49_TRTEINS_Peau
# 3718                                             demang  #6-49_TRTEINS_Peau
# 3781                                          pied roug  #6-49_TRTEINS_Peau
# 3876                                            es_peau  #6-49_TRTEINS_Peau
# 3897                                   radiotherap peau  #6-49_TRTEINS_Peau
# 3967                                                pel  #6-49_TRTEINS_Peau
# 4002                                  peau chimiotherap  #6-49_TRTEINS_Peau
# 4049                                  chimiotherap peau  #6-49_TRTEINS_Peau
# 4070                                         crem surgr  #6-49_TRTEINS_Peau
# 4085                                          peau roug  #6-49_TRTEINS_Peau
# 4127                                  peau chimiotherap  #6-49_TRTEINS_Peau
# 4169                                        cur thermal  #6-49_TRTEINS_Peau
# 4175                                   demageaison peau  #6-49_TRTEINS_Peau
# 4194                                      nettoyag peau  #6-49_TRTEINS_Peau
# 4209                                          canc peau  #6-49_TRTEINS_Peau
# 4282                                          peau roug  #6-49_TRTEINS_Peau
# 4318                                  chimiotherap peau  #6-49_TRTEINS_Peau
# 4338                                      produit lavag  #6-49_TRTEINS_Peau
# 4340                                  chang aspect peau  #6-49_TRTEINS_Peau
# 4349                                          peau canc  #6-49_TRTEINS_Peau
# 4357                     peux serv deodor niveau aissel  #6-49_TRTEINS_Peau
# 4365                                     canc sein peau  #6-49_TRTEINS_Peau
# 4366                                     secheress peau  #6-49_TRTEINS_Peau
# 4372                                        bouton peau  #6-49_TRTEINS_Peau
# 4376                                        crem hydrat  #6-49_TRTEINS_Peau
# 4385                                          crem rich  #6-49_TRTEINS_Peau
# 4388                                      soulag brulur  #6-49_TRTEINS_Peau
# 4393                                          main roug  #6-49_TRTEINS_Peau
# 4420                                        savon neutr  #6-49_TRTEINS_Peau
# 4489                                  secheress vaginal  #6-49_TRTEINS_Peau
#
#                        BlockId       Action
# 9     59918cf1e4b0feb28881fd9f  wiki_cancer
# 39    59918cf1e4b0feb28881fd9f  wiki_cancer
# 43    59918cf1e4b0feb28881fd9f  wiki_cancer
# 66    59918cf1e4b0feb28881fd9f  wiki_cancer
# 82    59918cf1e4b0feb28881fd9f  wiki_cancer
# 88    59918cf1e4b0feb28881fd9f  wiki_cancer
# 92    59918cf1e4b0feb28881fd9f  wiki_cancer
# 95    59918cf1e4b0feb28881fd9f  wiki_cancer
# 109   59918cf1e4b0feb28881fd9f  wiki_cancer
# 149   59918cf1e4b0feb28881fd9f  wiki_cancer
# 152   59918cf1e4b0feb28881fd9f  wiki_cancer
# 174   59918cf1e4b0feb28881fd9f  wiki_cancer
# 205   59918cf1e4b0feb28881fd9f  wiki_cancer
# 210   59918cf1e4b0feb28881fd9f  wiki_cancer
# 251   59918cf1e4b0feb28881fd9f  wiki_cancer
# 261   59918cf1e4b0feb28881fd9f  wiki_cancer
# 264   59918cf1e4b0feb28881fd9f  wiki_cancer
# 283   59918cf1e4b0feb28881fd9f  wiki_cancer
# 284   59918cf1e4b0feb28881fd9f  wiki_cancer
# 292   59918cf1e4b0feb28881fd9f  wiki_cancer
# 344   59918cf1e4b0feb28881fd9f  wiki_cancer
# 352   59918cf1e4b0feb28881fd9f  wiki_cancer
# 398   59918cf1e4b0feb28881fd9f  wiki_cancer
# 440   59918cf1e4b0feb28881fd9f  wiki_cancer
# 450   59918cf1e4b0feb28881fd9f  wiki_cancer
# 484   59918cf1e4b0feb28881fd9f  wiki_cancer
# 491   59918cf1e4b0feb28881fd9f  wiki_cancer
# 508   59918cf1e4b0feb28881fd9f  wiki_cancer
# 668   59918cf1e4b0feb28881fd9f  wiki_cancer
# 673   59918cf1e4b0feb28881fd9f  wiki_cancer
# ...                        ...          ...
# 3704  59918cf1e4b0feb28881fd9f  wiki_cancer
# 3718  59918cf1e4b0feb28881fd9f  wiki_cancer
# 3781  59918cf1e4b0feb28881fd9f  wiki_cancer
# 3876  59918cf1e4b0feb28881fd9f  wiki_cancer
# 3897  59918cf1e4b0feb28881fd9f  wiki_cancer
# 3967  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4002  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4049  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4070  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4085  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4127  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4169  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4175  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4194  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4209  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4282  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4318  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4338  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4340  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4349  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4357  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4365  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4366  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4372  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4376  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4385  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4388  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4393  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4420  59918cf1e4b0feb28881fd9f  wiki_cancer
# 4489  59918cf1e4b0feb28881fd9f  wiki_cancer
#
# [190 rows x 4 columns]

# %%
description2 = df
description2.to_csv('Intent.csv', sep = ',')

# %%
from os import path
from wordcloud import WordCloud

#d = path.dirname()

# Read the whole text.
#text = open(path.join(d, 'constitution.txt')).read()
text = open(path.join(DATA_DIR, 'Question.csv')).read()
# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:
#import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# The pil way (if you don't have matplotlib)
# image = wordcloud.to_image()
# image.show()

# %% [markdown]
# ## 3 Construction des caractéristiques ou *features* (TF-IDF)¶
# ### Introduction
# La vectorisation, c'est-à-dire la construction des caractéristiques à partir de la liste des mots se fait en 2 étapes:
# * **Hashage**. Il permet de réduire l'espace des variables (taille du dictionnaire) en un nombre limité et fixé a priori `n_hash` de caractéristiques. Il repose sur la définition d'une fonction de hashage, $h$ qui à un indice $j$ défini dans l'espace des entiers naturels, renvoie un indice $i=h(j)$ dans dans l'espace réduit (1 à n_hash) des caractéristiques. Ainsi le poids de l'indice $i$, du nouvel espace, est l'association de tous les poids d'indice $j$ tels que $i=h(j)$ de l'espace originale. Ici, les poids sont associés d'après la méthode décrite par Weinberger et al. (2009).
#
# N.B. $h$ n'est pas généré aléatoirement. Ainsi pour un même fichier d'apprentissage (ou de test) et pour un même entier n_hash, le résultat de la fonction de hashage est identique
#
# * **TF-IDF**. Le TF-IDF permet de faire ressortir l'importance relative de chaque mot $m$ (ou couples de mots consécutifs) dans un texte-produit ou un descriptif $d$, par rapport à la liste entière des produits. La fonction $TF(m,d)$ compte le nombre d'occurences du mot $m$ dans le descriptif $d$. La fonction $IDF(m)$ mesure l'importance du terme dans l'ensemble des documents ou descriptifs en donnant plus de poids aux termes les moins fréquents car considérés comme les plus discriminants (motivation analogue à celle de la métrique du chi2 en anamlyse des correspondance). $IDF(m,l)=\log\frac{D}{f(m)}$ où $D$ est le nombre de documents, la taille de l'échantillon d'apprentissage, et $f(m)$ le nombre de documents ou descriptifs contenant le mot $m$. La nouvelle variable ou *features* est $V_m(l)=TF(m,l)\times IDF(m,l)$.
#
# * Comme pour les transformations des variables quantitatives (centrage, réduction), la même transformation c'est-à-dire les mêmes pondérations, est calculée sur l'achantillon d'apprentissage et appliquée à celui de test.

# %% [markdown]
# ### Fonction de Vectorisation

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer
from sklearn.feature_extraction import FeatureHasher

# %% [markdown]
# ##### Vectorisation avec tf et idf

# %%
stop_words = nltk.corpus.stopwords.words('french')
question = data_train_clean["Question"] #on va travailler que sur la colonne des questions
vec = TfidfVectorizer(
            min_df = 1,
            stop_words =stop_words,
            smooth_idf=True,
            norm='l2',
            sublinear_tf=True,
            use_idf=True, #tf avec idf
            ngram_range=(1,2)) #bi-grams
tfidf =  vec.fit_transform(question)

# %%
#dimension de la matrice sparse des poids
np.shape(tfidf)
# Out:
# (4511, 7704)

# %%
# définition de la commande
X = tfidf
svd = TruncatedSVD(n_components=30, n_iter=40, random_state=42)
svd.fit(X)
#variance expliquee
print(svd.explained_variance_ratio_) 
print (" ")
#valeurs singuliere
print(svd.singular_values_)
# Out:
# [ 0.00806253  0.0059653   0.00662644  0.00574843  0.00590039  0.00525033
#   0.00500695  0.00472118  0.00455113  0.00436114  0.00436546  0.00430036
#   0.00414967  0.00406188  0.00389622  0.00381618  0.00381381  0.00373722
#   0.00360273  0.00346438  0.00325418  0.00321865  0.00314424  0.00309065
#   0.00305484  0.00296709  0.00291072  0.00284167  0.00274751  0.00278545]
#
# [ 6.65675175  5.64553743  5.4598823   5.17554484  5.16351031  4.95148231
#   4.78604609  4.63187515  4.51659507  4.48278224  4.44830217  4.38818266
#   4.31137641  4.26619307  4.18099495  4.15711652  4.13231841  4.10503879
#   4.03295092  3.94996789  3.85229687  3.80426936  3.76357647  3.72136364
#   3.70059636  3.647736    3.61067548  3.56835635  3.54368019  3.5314817 ]

# %%
# Eboulis des valeurs propres
plt.figure()
x = np.arange(30)
plt.bar(x,svd.explained_variance_)
plt.title("Eigenvalues")
plt.show()

# %% [markdown]
# ##### Question : comment chopper le nom des variables, vu qu'on a vectorisé notre data frame ?

# %%
# composantes principales
C = svd.fit(X).transform(X) #acp brute

#affiche de l'acp brute
#on multiplie toutes nos composantes principales par une constante pour avoir des graphes plus visibles
coord1=svd.components_[0]*np.sqrt(svd.explained_variance_[0])*25
coord2=svd.components_[1]*np.sqrt(svd.explained_variance_[1])*25
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1, 1, 1)
for i, j in zip(coord1,coord2):
    #plt.text(i, j,nom)
    plt.arrow(0,0,i,j,color='r')
plt.axis((-1.2,2,-1.2,2))
plt.title("Variables factor map (PCA)")
ax.set_xlabel('Dim 1 ')
ax.set_ylabel('Dim 2')
plt.show()

# %% [markdown]
# Deux variables tirent l'informations, si on couple avec le graphe wordcloud on peut penser que ce sont cancer et chimio

# %%
#ACP centree reduite

# composantes principales

CR = svd.fit(X).transform(X) #acp brute

#affiche de l'acp brute
#on multiplie toutes nos composantes principales par une constante pour avoir des graphes plus visibles
coord1=svd.components_[0]*np.sqrt(svd.explained_variance_[0])*25
coord2=svd.components_[1]*np.sqrt(svd.explained_variance_[1])*25
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1, 1, 1)
for i, j in zip(coord1,coord2):
    #plt.text(i, j,nom)
    plt.arrow(0,0,i,j,color='r')
plt.axis((-1.2,2,-1.2,2))
plt.title("Variables factor map (PCA)")
ax.set_xlabel('Dim 1 ')
ax.set_ylabel('Dim 2')
plt.show()

# %% [markdown]
# ##### Vectorisation avec tf sansidf
