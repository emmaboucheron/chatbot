# %%
#Importation des librairies utilisées
import unicodedata 
import time
import pandas as pd
import numpy as np
import random
import nltk
import collections
import itertools
import csv
import warnings

from sklearn.cross_validation import train_test_split
from sklearn.decomposition import TruncatedSVD
import matplotlib.pyplot as plt
# Out:
# /usr/local/insa/anaconda/envs/py27/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Répertoire de travail
DATA_DIR = "/home/bouchero/Documents/projet/"

# Nom des fichiers
training_reduit_path = DATA_DIR + "INSA_wefight_data_clean.csv"
# Variable Globale
HEADER_TEST = ['Question','Intent','BlockId', 'Action']
HEADER_TRAIN =['Question','Intent','BlockId', 'Action']

# %%
def split_dataset(input_path, nb_line, tauxValid,columns):
    time_start = time.time()
    data_all = pd.read_csv(input_path,sep=",",names=columns,nrows=nb_line) #cree data frame
    data_all = data_all.fillna("") #remplace les na par " "
    data_train, data_valid = train_test_split(data_all, test_size = tauxValid) # Split arrays or matrices into random train and test subsets
    time_end = time.time()
    print("Split Takes %d s" %(time_end-time_start))
    return data_train, data_valid

nb_line=20000  # part totale extraite du fichier initial ici déjà réduit
tauxValid=0.10 # part totale extraite du fichier initial ici déjà réduit
data_train, data_valid = split_dataset(training_reduit_path, nb_line, tauxValid, HEADER_TRAIN)
data_train.head()
# Out:
# Split Takes 0 s
#                            Question                           Intent  \
# 1013     chimio et perte de cheveux     #2-36_QVDP_Alopecie_Pourquoi
# 281                       Grossesse            #2-107_QVDP_Grossesse
# 360   cancer opération et grossesse  #2-111_QVDP_Grossesse_Chirurgie
# 1852      quand faire des siestes ?        #2-72_QVDP_Fatigue_Sieste
# 271    @Sexualite_Grossesse @Cancer            #2-107_QVDP_Grossesse
#
#                        BlockId       Action
# 1013  5984243ae4b03f0d12766ac7  wiki_cancer
# 281   598d6de3e4b03f0d40b7891f  wiki_cancer
# 360   598d6edce4b03f0d40bd4b11  wiki_cancer
# 1852  59846316e4b03f0d141962b2  wiki_cancer
# 271   598d6de3e4b03f0d40b7891f  wiki_cancer

# %%
# Librairies 
from bs4 import BeautifulSoup #Nettoyage d'HTML
import re # Regex
import nltk # Nettoyage des données

## listes de mots à supprimer dans la description des produits
## Depuis NLTK
nltk_stopwords = nltk.corpus.stopwords.words('french') 
## Depuis Un fichier externe.
lucene_stopwords = [unicode(w, "utf-8") for w in open(DATA_DIR+"lucene_stopwords.txt").read().split(",")] #En local

## Union des deux fichiers de stopwords 
stopwords = list(set(nltk_stopwords).union(set(lucene_stopwords)))

## Fonction de setmming de stemming permettant la racinisation
stemmer=nltk.stem.SnowballStemmer('french')

# %%
# Fonction clean générale
def clean_txt(txt):
    ### remove html stuff
    txt = BeautifulSoup(txt,"html.parser",from_encoding='utf-8').get_text() #nettoyage donnee html
    ### lower case
    txt = txt.lower()
    ### special escaping character '...'
    txt = txt.replace(u'\u2026','.')
    txt = txt.replace(u'\u00a0',' ')
    ### remove accent btw
    txt = unicodedata.normalize('NFD', txt).encode('ascii', 'ignore')
    ###txt = unidecode(txt)
    ### remove non alphanumeric char
    txt = re.sub('[^a-z_]', ' ', txt)
    ### remove french stop words
    tokens = [w for w in txt.split() if (len(w)>2) and (w not in stopwords)]
    ### french stemming
    tokens = [stemmer.stem(token) for token in tokens]
    #Stemmers remove morphological affixes from words, leaving only the word stem
    ### tokens = stemmer.stemWords(tokens)
    return ' '.join(tokens)
    #join() returns a string in which the string elements of sequence have been joined by str separator.

def clean_marque(txt):
    txt = re.sub('[^a-zA-Z0-9]', '_', txt).lower()
    return txt

# %%
# fonction de nettoyage du fichier(stemming et liste de mots à supprimer)
def clean_df(input_data, column_names= ['Question','Intent','BlockId', 'Action']):
    #Test if columns entry match columns names of input data
    column_names_diff= set(column_names).difference(set(input_data.columns))
    #set.difference   new set with elements in column_names but not in input_data.columns
    
    if column_names_diff: #rentre dans la boucle si column_names différent zero
        # warning = exception
        warnings.warn("Column(s) '"+", ".join(list(column_names_diff)) +"' do(es) not match columns of input data", Warning)
        
    nb_line = input_data.shape[0]
    print("Start Clean %d lines" %nb_line)
    
    # Cleaning start for each columns
    time_start = time.time()
    clean_list=[]
    for column_name in column_names:
        column = input_data[column_name].values
        if column_name == "Question":
            array_clean = np.array(map(clean_txt,column))
            
        elif column_name == "Intent":
            array_clean = np.asarray(input_data['Intent']) #on recopie telle quelle la colonne intent  
            
        else:
            array_clean = np.array(map(clean_marque,column))
            #applies a function to all the items in an input_list
            #map(function_to_apply, list_of_inputs)
        clean_list.append(array_clean)
    time_end = time.time()
    print("Cleaning time: %d secondes"%(time_end-time_start))
    
    #Convert list to DataFrame
    array_clean = np.array(clean_list).T
    data_clean = pd.DataFrame(array_clean, columns = column_names)
    return data_clean

# %%
stopwords_perso = ["veux", "apres", "faire", "peux", "dois", "vais", "peut", "fait"]
stopwords2 = list(set(stopwords).union(set(stopwords_perso)))

# Fonction clean générale
def clean_txt2(txt):
    ### remove html stuff
    txt = BeautifulSoup(txt,"html.parser",from_encoding='utf-8').get_text() #nettoyage donnee html
    ### lower case
    txt = txt.lower()
    ### special escaping character '...'
    txt = txt.replace(u'\u2026','.')
    txt = txt.replace(u'\u00a0',' ')
    ### remove accent btw
    txt = unicodedata.normalize('NFD', txt).encode('ascii', 'ignore')
    ###txt = unidecode(txt)
    ### remove non alphanumeric char
    txt = re.sub('[^a-z_]', ' ', txt)
    ### remove french stop words
    tokens = [w for w in txt.split() if (len(w)>2) and (w not in stopwords2)]
    ### french stemming
    tokens = [stemmer.stem(token) for token in tokens]
    #Stemmers remove morphological affixes from words, leaving only the word stem
    ### tokens = stemmer.stemWords(tokens)
    return ' '.join(tokens)
    #join() returns a string in which the string elements of sequence have been joined by str separator.

    # fonction de nettoyage du fichier(stemming et liste de mots à supprimer)
def clean_df2(input_data, column_names= ['Question','Intent','BlockId', 'Action']):
    #Test if columns entry match columns names of input data
    column_names_diff= set(column_names).difference(set(input_data.columns))
    #set.difference   new set with elements in column_names but not in input_data.columns
    
    if column_names_diff: #rentre dans la boucle si column_names différent zero
        # warning = exception
        warnings.warn("Column(s) '"+", ".join(list(column_names_diff)) +"' do(es) not match columns of input data", Warning)
        
    nb_line = input_data.shape[0]
    print("Start Clean %d lines" %nb_line)
    
    # Cleaning start for each columns
    time_start = time.time()
    clean_list=[]
    for column_name in column_names:
        column = input_data[column_name].values
        if column_name == "Question":
            array_clean = np.array(map(clean_txt2,column))
            
        elif column_name == "Intent":
            array_clean = np.asarray(input_data['Intent']) #on recopie telle quelle la colonne intent  
            
        else:
            array_clean = np.array(map(clean_marque,column))
            #applies a function to all the items in an input_list
            #map(function_to_apply, list_of_inputs)
        clean_list.append(array_clean)
    time_end = time.time()
    print("Cleaning time: %d secondes"%(time_end-time_start))
    
    #Convert list to DataFrame
    array_clean = np.array(clean_list).T
    data_clean = pd.DataFrame(array_clean, columns = column_names)
    return data_clean

data_valid_clean1 = clean_df2(data_valid)
data_train_clean1 = clean_df2(data_train)
# Out:
# Start Clean 502 lines
# Cleaning time: 0 secondes
# Start Clean 4511 lines
# Cleaning time: 1 secondes

# %%
# Take approximately 2 minutes fors 100.000 rows
data_valid_clean = clean_df(data_valid)
data_train_clean = clean_df(data_train)
# Out:
# Start Clean 502 lines
# Cleaning time: 1 secondes
# Start Clean 4511 lines
# Cleaning time: 4 secondes

# %%
data_train_cleanOrigin = data_train_clean1

# %%
np.shape(data_train_clean1)
# Out:
# (4511, 4)

# %%
#effectif de chaque categories
CatCount= collections.Counter(data_train_cleanOrigin['Intent']).items()
CatCount
# Out:
# [('#2-135_QVDP_Alimentation_Alcool', 22),
#  ('#2-55_QVDP_Douleur', 79),
#  ('#5-37_Soutien_Psychologique', 52),
#  ('#2-97_QVDP_ResteACharge', 24),
#  ('#2-60_QVDP_RadioT_Diarrh\xc3\x83\xc2\xa9e', 18),
#  ('Profile_write_role', 1),
#  ('#1-5_Menu_Aidant', 43),
#  ('#6-41_TRTEINS_ManchonLymphodeme', 37),
#  ('#8-9_DDP_Charte_patient', 7),
#  ('#6-6_TRTEINS_ChimioOrale', 18),
#  ('#6-35_TRTEINS_PrevenirLymphoedeme', 6),
#  ('#6-63_TRTEINS_PAC_Precautions', 15),
#  ('#2-125_QVDP_Sexualite_Reconstruction', 50),
#  ('#6-57_TRTEINS_Yeux_Secs', 79),
#  ('#6-44_TRTEINS_AllergieManchon', 8),
#  ('Profile_write_nomTraitement', 1),
#  ('#9-53_Informations_depistagesein', 44),
#  ('#2-122_QVDP_Sexualite_Alopecie', 12),
#  ('#2-58_QVDP_RadioT_Eff', 24),
#  ('#2-36_QVDP_Alopecie_Pourquoi', 99),
#  ('#6-5_TRTEINS_ChimioInjectable', 4),
#  ('#2-130_QVDP_Alimentation', 119),
#  ('#9-53_Depistage_cancer_sein', 8),
#  ('#2-53_QVDP_Cils', 29),
#  ('Conversation_Historique', 6),
#  ('#6-96_TRTEINS_Perte_Poids', 68),
#  ('#2-75_QVDP_SportPrecautions', 16),
#  ('#6-31_TRTEINS_Effetsecondaireshormonotherapie', 46),
#  ('#2-118_QVDP_Grossesse_Malformations', 14),
#  ('#8-11_DDP_Dossier_medical', 5),
#  ('#6-9_TRTEINS_ChimioIntraperitoneale', 13),
#  ('#6-22_TRTEINS_EffetsecondairesRadiotherapie', 13),
#  ('#2-107_QVDP_Grossesse', 57),
#  ('#6-67_TRTEINS_Chirurgie_Questions', 10),
#  ('#7-52_Remission', 29),
#  ('#6-47_TRTEINS_InfectionManchon', 3),
#  ('#001_Abonnement', 1),
#  ('Profile_write_recevoirTemoignage', 1),
#  ('#2-52_QVDP_Ongles', 26),
#  ('#001_Gestion_Abonnement', 35),
#  ('#2-106_QVDP_Social_HAD', 27),
#  ('#2-70_QVDP_Fatigue_Diminuer', 30),
#  ('#2-84_QVDP_Fertilite_GrossesseApresCancer', 32),
#  ('#6-73_TRTEINS_Chirurgie_Mastectomie', 51),
#  ('#6-53_TRTEINS_Aphtes', 111),
#  ('#8-8_DDP_Fin_de_vie', 7),
#  ('#2-96_QVDP_Social_Priseencharge', 70),
#  ('#2-137_QVDP_Alimentation_Remboursement', 18),
#  ('#2-133_QVDP_RegimeAnticancer', 23),
#  ('#000_Menu_General', 8),
#  ('Profile_write_typeTraitement', 2),
#  ('#6-68_TRTEINS_Chirurgie_Anesthesie', 3),
#  ('#2-121_QVDP_Sexualite_Cicatrice', 17),
#  ('#6-40_TRTEINS_PressotherapieLymphodeme', 23),
#  ('#6-1_TRTEINS_Chimiotherapie', 76),
#  ('#2-47_QVDP_Alopecie_CoutPerruque', 21),
#  ('#8-6_DDP_Consentement_eclaire', 10),
#  ('#6-64_TRTEINS_PAC_Risques', 23),
#  ('#1-4_Menu_Patient_Recent', 8),
#  ('#6-49_TRTEINS_Peau', 196),
#  ('#6-97_TRTEINS_Nausees_Vomissements', 130),
#  ('#2-49_QVDP_Alopecie_OuPerruque', 31),
#  ('#2-103_QVDP_Social_Banque', 35),
#  ('#2-61_QVDP_RadioT_Peau', 34),
#  ('#6-86_TRTEINS_Chirurgie_Reeducation', 8),
#  ('Profile_write_newsletter', 2),
#  ('#6-98_TRTEINS_EI_Frequents', 101),
#  ('#2-38_QVDP_Alopecie_Repousse', 41),
#  ('#7-58_Recidive', 15),
#  ('#6-72_TRTEINS_Chirurgie_Cicatrice', 17),
#  ('#6-37_TRTEINS_TrtLymphodeme', 12),
#  ('#2-59_QVDP_RadioT_Fatigue', 22),
#  ('#2-87_QVDP_Fertilite', 31),
#  ('#2-110_QVDP_Grossesse_Radiotherapie', 16),
#  ('Profile_write_age', 4),
#  ('#1-8_Menu_Traitement', 16),
#  ('#7-60_QVDA_Soins_Palliatifs', 5),
#  ('#2-72_QVDP_Fatigue_Sieste', 24),
#  ('Profile_read', 10),
#  ('intent', 1),
#  ('#9-13_Informations_metastase', 28),
#  ('#6-18_TRTEINS_Radiotherapie', 84),
#  ('#2-56_QVDP_DiminuerDouleur', 14),
#  ('#2-88_Reprise_Cycle', 7),
#  ('Profile_update', 7),
#  ('#2-93_QVDP_Social_Proches', 18),
#  ('#2-126_QVDP_Sexualite_BaisseLibido', 23),
#  ('#6-65_TRTEINS_Chirurgie', 37),
#  ('#2-134_QVDP_Alimentation_Citron', 19),
#  ('#2-65_QVDP_Fatigue_Hormono', 14),
#  ('#2-37_QVDP_Alopecie_Quand', 36),
#  ('#2-124_QVDP_Sexualite_PerteConfiance', 12),
#  ('#6-90_TRTEINS_Mauvais_Gout', 103),
#  ('#6-8_TRTEINS_Intrathecale', 12),
#  ('#2-101_QVDP_Social_RbProthese', 16),
#  ('#6-2_TRTEINS_Cycles', 11),
#  ('#6-43_TRTEINS_PrixManchon', 13),
#  ('#2-128_QVDP_Sexualite_Couple', 51),
#  ('#2-120_QVDP_Sexualite', 54),
#  ('#2-90_QVDP_Fertilite_Ponction', 29),
#  ('#2-41_QVDP_Alopecie_Diminuer', 49),
#  ('#2-115_QVDP_Grossesse_Allaitement', 40),
#  ('#7-49_QVDA_Personne_de_confiance', 9),
#  ('#6-73_TRTEINS_Chirurgie_Curage_axillaire', 28),
#  ('#9-2_Informations_cancer', 98),
#  ('Profile_write_typeCancer', 1),
#  ('#2-79_QVDP_SportQuel', 29),
#  ('#6-39_TRTEINS_DrainageLymphodeme', 17),
#  ('Conversation_rappel_read', 31),
#  ('#6-33_TRTEINS_Lymphe', 15),
#  ('#6-23_TRTEINS_SeanceRadiotherapie', 15),
#  ('#6-91_TRTEINS_Ballonnement', 10),
#  ('#2-64-0_QVDP_Fatigue', 83),
#  ('#6-81_TRTEINS_Chirurgie_Mastectomie_risques', 7),
#  ('#2-109_QVDP_Grossesse_Chimiotherapie', 30),
#  ('#2-64_QVDP_Fatigue_Chimio', 18),
#  ('#2-48_QVDP_Alopecie_RbPerruque', 33),
#  ('#6-34_TRTEINS_Lymphoedeme', 58),
#  ('#2-100_QVDP_Social_Transports', 11),
#  ('#2-45_QVDP_Alopecie_Perruque', 73),
#  ('#6-12_TRTEINS_ChimioAmbulatoire', 18),
#  ('#6-95_TRTEINS_Perte_Appetit', 44),
#  ('#6-92_TRTEINS_Diarrhee', 130),
#  ('#2-73_QVDP_Sport', 49),
#  ('Conversation_rappel_update', 3),
#  ('#6-60_TRTEINS_PAC', 99),
#  ('#6-13_TRTEINS_PreparationChimio', 17),
#  ('#8-13_DDP_Secret_medical', 6),
#  ('#6-58_TRTEINS_Bouche_Seche', 68),
#  ('#6-83_TRTEINS_Prothese', 22),
#  ('#2-123_QVDP_Sexualite_Prothese', 15),
#  ('#2-88_QVDP_Fertilite_Cycles', 6),
#  ('#2-102_QVDP_Social_RbPerruque', 16),
#  ('Conversation_rappel_update2', 18),
#  ('#6-24_TRTEINS_hormonotherapie', 66),
#  ('#9-20_Informations_Stades', 20),
#  ('#2-111_QVDP_Grossesse_Chirurgie', 16),
#  ('#2-112_QVDP_Grossesse_Hormonotherapie', 11),
#  ('#6-93_TRTEINS_Mauvaise_Haleine', 52),
#  ('#2-42_QVDP_Alopecie_Casque', 26),
#  ('Profile_write_rappels', 2),
#  ('Profile_write_doseTraitement', 4),
#  ('#2-85_QVDP_Fertilite_Preserver', 12),
#  ('#6-94_TRTEINS_Deglutition', 15),
#  ('conversation_rappel_rendezvous', 80)]

# %%
#on echantillonne pour avoir le même nbre de questions dans chaque categorie
for k in range (np.shape(CatCount)[0]):
    if (CatCount[k][1] < 193): #le plus quand nbre de question est 193
        DfCat = (data_train_clean1.loc[data_train_clean1['Intent']== CatCount[k][0],:]) #con recupere les dataframe avec l'intent souhaite
        nbreLigneManquant = 193 - CatCount[k][1] #on regarde combien il manque de question
        if nbreLigneManquant < np.shape(DfCat)[0]: #lorsque on doit prendre quelques colonnes on tire aleatoirement
            DfCatRand = DfCat.sample(n=nbreLigneManquant)
            data_train_clean = pd.concat([data_train_clean1, DfCatRand], ignore_index=True)#on concatene avec l'ancien dataframe        
        else:
            taille = np.shape(DfCat)[0]
            DfCatTemp = DfCat.append([DfCat]*193,ignore_index=True) #on cree un dataframe des categories manquante assez gros pour pouvoirtirer aleatoirement les questions qu'on garde
            DfCatTemp = DfCatTemp.sample(n=nbreLigneManquant)
            data_train_clean1 = pd.concat([data_train_clean1, DfCatTemp], ignore_index=True)
np.shape(data_train_clean)
# Out:
# (24140, 4)

# %%
CatCount= collections.Counter(data_train_clean1['Intent']).items()
CatCount
# Out:
# [('#2-135_QVDP_Alimentation_Alcool', 193),
#  ('#2-55_QVDP_Douleur', 193),
#  ('#5-37_Soutien_Psychologique', 193),
#  ('#2-97_QVDP_ResteACharge', 193),
#  ('#2-60_QVDP_RadioT_Diarrh\xc3\x83\xc2\xa9e', 193),
#  ('Profile_write_role', 193),
#  ('#1-5_Menu_Aidant', 193),
#  ('#6-41_TRTEINS_ManchonLymphodeme', 193),
#  ('#8-9_DDP_Charte_patient', 193),
#  ('#6-6_TRTEINS_ChimioOrale', 193),
#  ('#6-35_TRTEINS_PrevenirLymphoedeme', 193),
#  ('#6-63_TRTEINS_PAC_Precautions', 193),
#  ('#2-125_QVDP_Sexualite_Reconstruction', 193),
#  ('#6-57_TRTEINS_Yeux_Secs', 193),
#  ('#6-44_TRTEINS_AllergieManchon', 193),
#  ('Profile_write_nomTraitement', 193),
#  ('#9-53_Informations_depistagesein', 193),
#  ('#2-122_QVDP_Sexualite_Alopecie', 193),
#  ('#2-58_QVDP_RadioT_Eff', 193),
#  ('#2-36_QVDP_Alopecie_Pourquoi', 99),
#  ('#6-5_TRTEINS_ChimioInjectable', 193),
#  ('#2-130_QVDP_Alimentation', 119),
#  ('#9-53_Depistage_cancer_sein', 193),
#  ('#2-53_QVDP_Cils', 193),
#  ('Conversation_Historique', 193),
#  ('#6-96_TRTEINS_Perte_Poids', 193),
#  ('#2-75_QVDP_SportPrecautions', 193),
#  ('#6-31_TRTEINS_Effetsecondaireshormonotherapie', 193),
#  ('#2-118_QVDP_Grossesse_Malformations', 193),
#  ('#8-11_DDP_Dossier_medical', 193),
#  ('#6-9_TRTEINS_ChimioIntraperitoneale', 193),
#  ('#6-22_TRTEINS_EffetsecondairesRadiotherapie', 193),
#  ('#2-107_QVDP_Grossesse', 193),
#  ('#6-67_TRTEINS_Chirurgie_Questions', 193),
#  ('#7-52_Remission', 193),
#  ('#6-47_TRTEINS_InfectionManchon', 193),
#  ('#001_Abonnement', 193),
#  ('Profile_write_recevoirTemoignage', 193),
#  ('#2-52_QVDP_Ongles', 193),
#  ('#001_Gestion_Abonnement', 193),
#  ('#2-106_QVDP_Social_HAD', 193),
#  ('#2-70_QVDP_Fatigue_Diminuer', 193),
#  ('#2-84_QVDP_Fertilite_GrossesseApresCancer', 193),
#  ('#6-73_TRTEINS_Chirurgie_Mastectomie', 193),
#  ('#6-53_TRTEINS_Aphtes', 111),
#  ('#8-8_DDP_Fin_de_vie', 193),
#  ('#2-96_QVDP_Social_Priseencharge', 193),
#  ('#2-137_QVDP_Alimentation_Remboursement', 193),
#  ('#2-133_QVDP_RegimeAnticancer', 193),
#  ('#000_Menu_General', 193),
#  ('Profile_write_typeTraitement', 193),
#  ('#6-68_TRTEINS_Chirurgie_Anesthesie', 193),
#  ('#2-121_QVDP_Sexualite_Cicatrice', 193),
#  ('#6-40_TRTEINS_PressotherapieLymphodeme', 193),
#  ('#6-1_TRTEINS_Chimiotherapie', 193),
#  ('#2-47_QVDP_Alopecie_CoutPerruque', 193),
#  ('#8-6_DDP_Consentement_eclaire', 193),
#  ('#6-64_TRTEINS_PAC_Risques', 193),
#  ('#1-4_Menu_Patient_Recent', 193),
#  ('#6-49_TRTEINS_Peau', 196),
#  ('#6-97_TRTEINS_Nausees_Vomissements', 130),
#  ('#2-49_QVDP_Alopecie_OuPerruque', 193),
#  ('#2-103_QVDP_Social_Banque', 193),
#  ('#2-61_QVDP_RadioT_Peau', 193),
#  ('#6-86_TRTEINS_Chirurgie_Reeducation', 193),
#  ('Profile_write_newsletter', 193),
#  ('#6-98_TRTEINS_EI_Frequents', 101),
#  ('#2-38_QVDP_Alopecie_Repousse', 193),
#  ('#7-58_Recidive', 193),
#  ('#6-72_TRTEINS_Chirurgie_Cicatrice', 193),
#  ('#6-37_TRTEINS_TrtLymphodeme', 193),
#  ('#2-59_QVDP_RadioT_Fatigue', 193),
#  ('#2-87_QVDP_Fertilite', 193),
#  ('#2-110_QVDP_Grossesse_Radiotherapie', 193),
#  ('Profile_write_age', 193),
#  ('#1-8_Menu_Traitement', 193),
#  ('#7-60_QVDA_Soins_Palliatifs', 193),
#  ('#2-72_QVDP_Fatigue_Sieste', 193),
#  ('Profile_read', 193),
#  ('intent', 193),
#  ('#9-13_Informations_metastase', 193),
#  ('#6-18_TRTEINS_Radiotherapie', 193),
#  ('#2-56_QVDP_DiminuerDouleur', 193),
#  ('#2-88_Reprise_Cycle', 193),
#  ('Profile_update', 193),
#  ('#2-93_QVDP_Social_Proches', 193),
#  ('#2-126_QVDP_Sexualite_BaisseLibido', 193),
#  ('#6-65_TRTEINS_Chirurgie', 193),
#  ('#2-134_QVDP_Alimentation_Citron', 193),
#  ('#2-65_QVDP_Fatigue_Hormono', 193),
#  ('#2-37_QVDP_Alopecie_Quand', 193),
#  ('#2-124_QVDP_Sexualite_PerteConfiance', 193),
#  ('#6-90_TRTEINS_Mauvais_Gout', 103),
#  ('#6-8_TRTEINS_Intrathecale', 193),
#  ('#2-101_QVDP_Social_RbProthese', 193),
#  ('#6-2_TRTEINS_Cycles', 193),
#  ('#6-43_TRTEINS_PrixManchon', 193),
#  ('#2-128_QVDP_Sexualite_Couple', 193),
#  ('#2-120_QVDP_Sexualite', 193),
#  ('#2-90_QVDP_Fertilite_Ponction', 193),
#  ('#2-41_QVDP_Alopecie_Diminuer', 193),
#  ('#2-115_QVDP_Grossesse_Allaitement', 193),
#  ('#7-49_QVDA_Personne_de_confiance', 193),
#  ('#6-73_TRTEINS_Chirurgie_Curage_axillaire', 193),
#  ('#9-2_Informations_cancer', 98),
#  ('Profile_write_typeCancer', 193),
#  ('#2-79_QVDP_SportQuel', 193),
#  ('#6-39_TRTEINS_DrainageLymphodeme', 193),
#  ('Conversation_rappel_read', 193),
#  ('#6-33_TRTEINS_Lymphe', 193),
#  ('#6-23_TRTEINS_SeanceRadiotherapie', 193),
#  ('#6-91_TRTEINS_Ballonnement', 193),
#  ('#2-64-0_QVDP_Fatigue', 193),
#  ('#6-81_TRTEINS_Chirurgie_Mastectomie_risques', 193),
#  ('#2-109_QVDP_Grossesse_Chimiotherapie', 193),
#  ('#2-64_QVDP_Fatigue_Chimio', 193),
#  ('#2-48_QVDP_Alopecie_RbPerruque', 193),
#  ('#6-34_TRTEINS_Lymphoedeme', 193),
#  ('#2-100_QVDP_Social_Transports', 193),
#  ('#2-45_QVDP_Alopecie_Perruque', 193),
#  ('#6-12_TRTEINS_ChimioAmbulatoire', 193),
#  ('#6-95_TRTEINS_Perte_Appetit', 193),
#  ('#6-92_TRTEINS_Diarrhee', 130),
#  ('#2-73_QVDP_Sport', 193),
#  ('Conversation_rappel_update', 193),
#  ('#6-60_TRTEINS_PAC', 99),
#  ('#6-13_TRTEINS_PreparationChimio', 193),
#  ('#8-13_DDP_Secret_medical', 193),
#  ('#6-58_TRTEINS_Bouche_Seche', 193),
#  ('#6-83_TRTEINS_Prothese', 193),
#  ('#2-123_QVDP_Sexualite_Prothese', 193),
#  ('#2-88_QVDP_Fertilite_Cycles', 193),
#  ('#2-102_QVDP_Social_RbPerruque', 193),
#  ('Conversation_rappel_update2', 193),
#  ('#6-24_TRTEINS_hormonotherapie', 193),
#  ('#9-20_Informations_Stades', 193),
#  ('#2-111_QVDP_Grossesse_Chirurgie', 193),
#  ('#2-112_QVDP_Grossesse_Hormonotherapie', 193),
#  ('#6-93_TRTEINS_Mauvaise_Haleine', 193),
#  ('#2-42_QVDP_Alopecie_Casque', 193),
#  ('Profile_write_rappels', 193),
#  ('Profile_write_doseTraitement', 193),
#  ('#2-85_QVDP_Fertilite_Preserver', 193),
#  ('#6-94_TRTEINS_Deglutition', 193),
#  ('conversation_rappel_rendezvous', 193)]

# %%
np.shape(data_train_clean1)
# Out:
# (27241, 4)

# %%
#L5 = (data_train_clean.loc[data_train_clean['Intent']=='#8-9_DDP_Charte_patient',:])

# %%
data_train_clean1
# Out:
#                                        Question  \
# 0                           chimio pert cheveux
# 1                                      grossess
# 2                            canc oper grossess
# 3                                         siest
# 4                       sexualite_grossess canc
# 5                                    infos canc
# 6                      cach cheveux lor repouss
# 7      pris charg securit social nouvel ald mem
# 8                                 perdr cheveux
# 9                              manchon compress
# 10                               sert port cath
# 11                            different manchon
# 12                                      enceint
# 13                      sign apparit lymphoedem
# 14                      cheveux commencent tomb
# 15                        prothes systemat oper
# 16                                          had
# 17                                 souffr mucit
# 18                                  ger angoiss
# 19                                     gingembr
# 20                  hello petit ganglion aissel
# 21                    oper pos question medecin
# 22                             support cicatric
# 23                            attent fais sport
# 24                                 bouch pateux
# 25            con chimiotherap intra peritoneal
# 26                                      emprunt
# 27                                   cest limph
# 28                                      vitamin
# 29                                    mastectom
# ...                                         ...
# 27211                                      rend
# 27212                                      rend
# 27213                  rend demain pourr rappel
# 27214                              rend septemb
# 27215              rappel aller medecin dimanch
# 27216                                  met rend
# 27217                                      rend
# 27218                                      rend
# 27219             rdv mercrd novembr eme chimio
# 27220          appel infirmier octobr pris sang
# 27221                              rend septemb
# 27222                                 rend mard
# 27223                             rend septembr
# 27224                                      rend
# 27225                             rend vou lund
# 27226                               rend demain
# 27227                                      rend
# 27228                           rend jeud matin
# 27229                                 rend mard
# 27230                                 rend aout
# 27231               rappel rend oncolog novembr
# 27232                                  met rend
# 27233                                      rend
# 27234                                      rend
# 27235             rappel rend lieu bastill aout
# 27236                                 rend mard
# 27237                                 rend mard
# 27238                                      rend
# 27239          appel infirmier octobr pris sang
# 27240                                 rend mard
#
#                                          Intent                   BlockId  \
# 0                  #2-36_QVDP_Alopecie_Pourquoi  5984243ae4b03f0d12766ac7
# 1                         #2-107_QVDP_Grossesse  598d6de3e4b03f0d40b7891f
# 2               #2-111_QVDP_Grossesse_Chirurgie  598d6edce4b03f0d40bd4b11
# 3                     #2-72_QVDP_Fatigue_Sieste  59846316e4b03f0d141962b2
# 4                         #2-107_QVDP_Grossesse  598d6de3e4b03f0d40b7891f
# 5                      #9-2_Informations_cancer  59632c41e4b0a226d067cd48
# 6                  #2-45_QVDP_Alopecie_Perruque  5984386ee4b03f0d12ec6c33
# 7               #2-96_QVDP_Social_Priseencharge  598b43bee4b03f0d36d5f410
# 8                  #2-41_QVDP_Alopecie_Diminuer  59843588e4b03f0d12d83b08
# 9               #6-41_TRTEINS_ManchonLymphodeme  598b5110e4b03f0d3718d13f
# 10                            #6-60_TRTEINS_PAC  59919288e4b0feb288a76cc3
# 11              #6-41_TRTEINS_ManchonLymphodeme  598b5110e4b03f0d3718d13f
# 12                        #2-107_QVDP_Grossesse  598d6de3e4b03f0d40b7891f
# 13                    #6-34_TRTEINS_Lymphoedeme  598b4f84e4b03f0d37111d5d
# 14                    #2-37_QVDP_Alopecie_Quand  5984342ae4b03f0d12ce91dc
# 15                       #6-83_TRTEINS_Prothese  59919701e4b0feb288c56a79
# 16                       #2-106_QVDP_Social_HAD  598b4541e4b03f0d36de29d9
# 17                         #6-53_TRTEINS_Aphtes  59918dbae4b0feb28887a14b
# 18                  #5-37_Soutien_Psychologique  59632c41e4b0a226d067c7ba
# 19                     #2-130_QVDP_Alimentation  5991c543e4b0b2045b0c568f
# 20     #6-73_TRTEINS_Chirurgie_Curage_axillaire  59919488e4b0feb288b498e5
# 21            #6-67_TRTEINS_Chirurgie_Questions  599193c2e4b0feb288af845e
# 22              #2-121_QVDP_Sexualite_Cicatrice  59918978e4b0feb2886aa614
# 23                  #2-75_QVDP_SportPrecautions  59895cc6e4b03f0d2cdb9a9c
# 24                   #6-58_TRTEINS_Bouche_Seche  59918e6ee4b0feb2888c9bcd
# 25          #6-9_TRTEINS_ChimioIntraperitoneale  59632c41e4b0a226d067cca8
# 26                    #2-103_QVDP_Social_Banque  598b44d9e4b03f0d36dbfd76
# 27                         #6-33_TRTEINS_Lymphe  598b4ed1e4b03f0d370da464
# 28                     #2-130_QVDP_Alimentation  5991c543e4b0b2045b0c568f
# 29          #6-73_TRTEINS_Chirurgie_Mastectomie  59919579e4b0feb288bb04a8
# ...                                         ...                       ...
# 27211            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27212            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27213            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27214            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27215            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27216            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27217            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27218            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27219            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27220            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27221            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27222            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27223            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27224            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27225            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27226            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27227            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27228            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27229            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27230            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27231            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27232            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27233            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27234            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27235            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27236            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27237            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27238            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27239            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27240            conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
#
#                               Action
# 0                        wiki_cancer
# 1                        wiki_cancer
# 2                        wiki_cancer
# 3                        wiki_cancer
# 4                        wiki_cancer
# 5                        wiki_cancer
# 6                        wiki_cancer
# 7                        wiki_cancer
# 8                        wiki_cancer
# 9                        wiki_cancer
# 10                       wiki_cancer
# 11                       wiki_cancer
# 12                       wiki_cancer
# 13                       wiki_cancer
# 14                       wiki_cancer
# 15                       wiki_cancer
# 16                       wiki_cancer
# 17                       wiki_cancer
# 18                       wiki_cancer
# 19                       wiki_cancer
# 20                       wiki_cancer
# 21                       wiki_cancer
# 22                       wiki_cancer
# 23                       wiki_cancer
# 24                       wiki_cancer
# 25                      wiki_cancer_
# 26                       wiki_cancer
# 27                       wiki_cancer
# 28                       wiki_cancer
# 29                       wiki_cancer
# ...                              ...
# 27211  conversation_rappelrendezvous
# 27212  conversation_rappelrendezvous
# 27213  conversation_rappelrendezvous
# 27214  conversation_rappelrendezvous
# 27215  conversation_rappelrendezvous
# 27216  conversation_rappelrendezvous
# 27217  conversation_rappelrendezvous
# 27218  conversation_rappelrendezvous
# 27219  conversation_rappelrendezvous
# 27220  conversation_rappelrendezvous
# 27221  conversation_rappelrendezvous
# 27222  conversation_rappelrendezvous
# 27223  conversation_rappelrendezvous
# 27224  conversation_rappelrendezvous
# 27225  conversation_rappelrendezvous
# 27226  conversation_rappelrendezvous
# 27227  conversation_rappelrendezvous
# 27228  conversation_rappelrendezvous
# 27229  conversation_rappelrendezvous
# 27230  conversation_rappelrendezvous
# 27231  conversation_rappelrendezvous
# 27232  conversation_rappelrendezvous
# 27233  conversation_rappelrendezvous
# 27234  conversation_rappelrendezvous
# 27235  conversation_rappelrendezvous
# 27236  conversation_rappelrendezvous
# 27237  conversation_rappelrendezvous
# 27238  conversation_rappelrendezvous
# 27239  conversation_rappelrendezvous
# 27240  conversation_rappelrendezvous
#
# [27241 rows x 4 columns]

# %%
#ajout d'un data frame ayant 2 lignes dont l intent est Charte patient
L5 = (data_train_clean1.loc[data_train_clean1['Intent']=='#8-9_DDP_Charte_patient',:])
L2 = L5.sample(n=3)
AAA = pd.concat([data_train_clean1, L2], ignore_index=True)

# %%
#ajout d'un data frame * 5 ayant 2 lignes dont l intent est Charte patient
#L5 = (data_train_clean.loc[data_train_clean['Intent']=='#8-9_DDP_Charte_patient',:])
#L2 = L5.sample(n=2)
#data_train_clean.append([L5]*5)

# %% [markdown]
# # Prediction

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer
from sklearn.feature_extraction import FeatureHasher

# %%
def vectorizer_train(df,column):
    col = df[column]
    # TFIDF
    vec = TfidfVectorizer(
            min_df = 1, #on prend tous les mots
            stop_words =stopwords,
            smooth_idf=True,
            norm='l2',
            sublinear_tf=True,
            use_idf=True, #tf avec idf
            ngram_range=(1,1)) 
    tfidf=vec.fit_transform(col)
    return vec,tfidf

def apply_vectorizer(df, vec, columns):
    
    data_hash = map(lambda x : " ".join(x), df[columns].values)  
    tfidf=vec.transform(df[columns])

    # TFIDF
    #tfidf=vec.transform(df)
    return tfidf

# %%
vec,X = vectorizer_train(data_train_clean1,"Question")
Y = data_train_clean1["Intent"].values
Xv = apply_vectorizer(data_valid_clean1,vec,"Question")
Yv = data_valid_clean1["Intent"].values

# %%
# Regression Logistique 
## estimation
from sklearn.linear_model import LogisticRegression
#si on augmente C, on augmente bcp le score
cla = LogisticRegression(penalty='l2', dual=False, tol=0.0001, C=1, fit_intercept=True,
                          intercept_scaling=1, class_weight=None, random_state=None, solver='liblinear',
                          max_iter=100, multi_class='ovr', verbose=0, warm_start=False, n_jobs=1)
cla.fit(X,Y)
score=cla.score(X,Y)
Y_predict = cla.predict(X)
                
print('# training score:',score)
# Out:
# ('# training score:', 0.95668294115487684)

# %%
## erreur en validation
scoreValidation=cla.score(Xv,Yv)
predict_v = cla.predict(Xv)
##probleme car tfidf et Xv pas le même nbre de colonne 
print('# validation score:',scoreValidation)
# Out:
# ('# validation score:', 0.68326693227091628)

# %% [markdown]
# Score d'apprentissage bien meilleur qu'avec les données brutes, mais le score de validation gagne que 2%
