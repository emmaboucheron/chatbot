# %%
#Importation des librairies utilisées
import unicodedata 
import time
import pandas as pd
import numpy as np
import random
import nltk
import collections
import itertools
import csv
import warnings

from sklearn.cross_validation import train_test_split
from sklearn.decomposition import TruncatedSVD
import matplotlib.pyplot as plt

# %%
# Répertoire de travail
DATA_DIR = "C:/Users/ETIENNE/Documents/Work/INSA/4A/Projets 4gmm 2018/"

# Nom des fichiers
training_reduit_path = DATA_DIR + "INSA_wefight_data_clean.csv"
# Variable Globale
HEADER_TEST = ['Question','Intent','BlockId', 'Action']
HEADER_TRAIN =['Question','Intent','BlockId', 'Action']

# %%
def split_dataset(input_path, nb_line, tauxValid,columns):
    time_start = time.time()
    data_all = pd.read_csv(input_path,sep=",",names=columns,nrows=nb_line) #cree data frame
    data_all = data_all.fillna("") #remplace les na par " "
    data_train, data_valid = train_test_split(data_all, test_size = tauxValid) # Split arrays or matrices into random train and test subsets
    time_end = time.time()
    print("Split Takes %d s" %(time_end-time_start))
    return data_train, data_valid

nb_line=20000  # part totale extraite du fichier initial ici déjà réduit
tauxValid=0.10 # part totale extraite du fichier initial ici déjà réduit
data_train, data_valid = split_dataset(training_reduit_path, nb_line, tauxValid, HEADER_TRAIN)
data_train.head()
# Out:
# Split Takes 3 s
#                                                Question  \
# 434   j'ai une une séance de rayon pendant que j'éta...
# 5001                              ma dose de traitement
# 3468                              PAC et chimiothérapie
# 2583  quels sont les effets du taxol et de l hormono...
# 1736  comment diminuer la fatigue après une mastecto...
#
#                                    Intent                   BlockId  \
# 434   #2-118_QVDP_Grossesse_Malformations  598d7089e4b03f0d40c73834
# 5001         Profile_write_doseTraitement  596340c2e4b0a226d0f53612
# 3468                    #6-60_TRTEINS_PAC  59919288e4b0feb288a76cc3
# 2583        #6-24_TRTEINS_hormonotherapie  59632c41e4b0a226d067cc6d
# 1736                 #2-64-0_QVDP_Fatigue  59942265e4b068eebf52bb9f
#
#                                              Action
# 434                                     wiki_cancer
# 5001  conversation_FichePatientWrite:doseTraitement
# 3468                                    wiki_cancer
# 2583                                    wiki_cancer
# 1736                                    wiki_cancer

# %%
# Librairies 
from bs4 import BeautifulSoup #Nettoyage d'HTML
import re # Regex
import nltk # Nettoyage des données

## listes de mots à supprimer dans la description des produits
## Depuis NLTK
nltk_stopwords = nltk.corpus.stopwords.words('french') 
## Depuis Un fichier externe.
lucene_stopwords = [unicode(w, "utf-8") for w in open(DATA_DIR+"lucene_stopwords.txt").read().split(",")] #En local

## Union des deux fichiers de stopwords 
stopwords = list(set(nltk_stopwords).union(set(lucene_stopwords)))

## Fonction de setmming de stemming permettant la racinisation
stemmer=nltk.stem.SnowballStemmer('french')

# %%
# Fonction clean générale
def clean_txt(txt):
    ### remove html stuff
    txt = BeautifulSoup(txt,"html.parser",from_encoding='utf-8').get_text() #nettoyage donnee html
    ### lower case
    txt = txt.lower()
    ### special escaping character '...'
    txt = txt.replace(u'\u2026','.')
    txt = txt.replace(u'\u00a0',' ')
    ### remove accent btw
    txt = unicodedata.normalize('NFD', txt).encode('ascii', 'ignore')
    ###txt = unidecode(txt)
    ### remove non alphanumeric char
    txt = re.sub('[^a-z_]', ' ', txt)
    ### remove french stop words
    tokens = [w for w in txt.split() if (len(w)>2) and (w not in stopwords)]
    ### french stemming
    tokens = [stemmer.stem(token) for token in tokens]
    #Stemmers remove morphological affixes from words, leaving only the word stem
    ### tokens = stemmer.stemWords(tokens)
    return ' '.join(tokens)
    #join() returns a string in which the string elements of sequence have been joined by str separator.

def clean_marque(txt):
    txt = re.sub('[^a-zA-Z0-9]', '_', txt).lower()
    return txt

# %%
# fonction de nettoyage du fichier(stemming et liste de mots à supprimer)
def clean_df(input_data, column_names= ['Question','Intent','BlockId', 'Action']):
    #Test if columns entry match columns names of input data
    column_names_diff= set(column_names).difference(set(input_data.columns))
    #set.difference   new set with elements in column_names but not in input_data.columns
    
    if column_names_diff: #rentre dans la boucle si column_names différent zero
        # warning = exception
        warnings.warn("Column(s) '"+", ".join(list(column_names_diff)) +"' do(es) not match columns of input data", Warning)
        
    nb_line = input_data.shape[0]
    print("Start Clean %d lines" %nb_line)
    
    # Cleaning start for each columns
    time_start = time.time()
    clean_list=[]
    for column_name in column_names:
        column = input_data[column_name].values
        if column_name == "Question":
            array_clean = np.array(map(clean_txt,column))
            
        elif column_name == "Intent":
            array_clean = np.asarray(input_data['Intent']) #on recopie telle quelle la colonne intent  
            
        else:
            array_clean = np.array(map(clean_marque,column))
            #applies a function to all the items in an input_list
            #map(function_to_apply, list_of_inputs)
        clean_list.append(array_clean)
    time_end = time.time()
    print("Cleaning time: %d secondes"%(time_end-time_start))
    
    #Convert list to DataFrame
    array_clean = np.array(clean_list).T
    data_clean = pd.DataFrame(array_clean, columns = column_names)
    return data_clean

# %%
# Take approximately 2 minutes fors 100.000 rows
data_valid_clean = clean_df(data_valid)
data_train_clean = clean_df(data_train)
# Out:
# Start Clean 502 lines
# Cleaning time: 1 secondes
# Start Clean 4511 lines
# Cleaning time: 4 secondes

# %%
data_train_cleanOrigin = data_train_clean

# %%
np.shape(data_train_clean)
# Out:
# (4511, 4)

# %%
#effectif de chaque categories
CatCount= collections.Counter(data_train_cleanOrigin['Intent']).items()
CatCount
# Out:
# [('#2-88_Reprise_Cycle', 7),
#  ('#2-135_QVDP_Alimentation_Alcool', 24),
#  ('#2-55_QVDP_Douleur', 78),
#  ('#5-37_Soutien_Psychologique', 52),
#  ('#2-97_QVDP_ResteACharge', 22),
#  ('#2-60_QVDP_RadioT_Diarrh\xc3\x83\xc2\xa9e', 20),
#  ('Profile_write_role', 1),
#  ('#1-5_Menu_Aidant', 39),
#  ('#6-41_TRTEINS_ManchonLymphodeme', 39),
#  ('#8-9_DDP_Charte_patient', 7),
#  ('#6-2_TRTEINS_Cycles', 14),
#  ('#6-35_TRTEINS_PrevenirLymphoedeme', 8),
#  ('#6-63_TRTEINS_PAC_Precautions', 13),
#  ('#2-125_QVDP_Sexualite_Reconstruction', 50),
#  ('#6-57_TRTEINS_Yeux_Secs', 77),
#  ('#6-44_TRTEINS_AllergieManchon', 9),
#  ('Profile_write_nomTraitement', 1),
#  ('#9-53_Informations_depistagesein', 48),
#  ('#2-122_QVDP_Sexualite_Alopecie', 12),
#  ('#2-58_QVDP_RadioT_Eff', 25),
#  ('#2-36_QVDP_Alopecie_Pourquoi', 104),
#  ('#6-5_TRTEINS_ChimioInjectable', 3),
#  ('#2-130_QVDP_Alimentation', 114),
#  ('#9-53_Depistage_cancer_sein', 8),
#  ('#2-75_QVDP_SportPrecautions', 17),
#  ('Conversation_Historique', 6),
#  ('#2-73_QVDP_Sport', 42),
#  ('#2-53_QVDP_Cils', 27),
#  ('#6-31_TRTEINS_Effetsecondaireshormonotherapie', 44),
#  ('#2-118_QVDP_Grossesse_Malformations', 15),
#  ('#8-11_DDP_Dossier_medical', 3),
#  ('#6-9_TRTEINS_ChimioIntraperitoneale', 12),
#  ('#2-107_QVDP_Grossesse', 57),
#  ('#6-67_TRTEINS_Chirurgie_Questions', 9),
#  ('#6-6_TRTEINS_ChimioOrale', 19),
#  ('#6-72_TRTEINS_Chirurgie_Cicatrice', 18),
#  ('#6-47_TRTEINS_InfectionManchon', 3),
#  ('Profile_write_recevoirTemoignage', 1),
#  ('#2-52_QVDP_Ongles', 25),
#  ('#001_Gestion_Abonnement', 37),
#  ('#2-106_QVDP_Social_HAD', 27),
#  ('#2-70_QVDP_Fatigue_Diminuer', 31),
#  ('#2-84_QVDP_Fertilite_GrossesseApresCancer', 34),
#  ('#6-73_TRTEINS_Chirurgie_Mastectomie', 54),
#  ('#6-53_TRTEINS_Aphtes', 111),
#  ('#8-8_DDP_Fin_de_vie', 7),
#  ('#2-96_QVDP_Social_Priseencharge', 68),
#  ('#2-137_QVDP_Alimentation_Remboursement', 20),
#  ('#2-100_QVDP_Social_Transports', 12),
#  ('#000_Menu_General', 8),
#  ('Profile_write_typeTraitement', 2),
#  ('#6-68_TRTEINS_Chirurgie_Anesthesie', 3),
#  ('#2-121_QVDP_Sexualite_Cicatrice', 16),
#  ('#6-40_TRTEINS_PressotherapieLymphodeme', 23),
#  ('#6-1_TRTEINS_Chimiotherapie', 75),
#  ('#2-47_QVDP_Alopecie_CoutPerruque', 20),
#  ('#8-6_DDP_Consentement_eclaire', 9),
#  ('#6-64_TRTEINS_PAC_Risques', 22),
#  ('#1-4_Menu_Patient_Recent', 9),
#  ('#9-20_Informations_Stades', 20),
#  ('#6-49_TRTEINS_Peau', 189),
#  ('#6-97_TRTEINS_Nausees_Vomissements', 126),
#  ('#2-49_QVDP_Alopecie_OuPerruque', 38),
#  ('#2-103_QVDP_Social_Banque', 38),
#  ('#2-61_QVDP_RadioT_Peau', 38),
#  ('#6-86_TRTEINS_Chirurgie_Reeducation', 9),
#  ('Profile_write_newsletter', 2),
#  ('#6-98_TRTEINS_EI_Frequents', 99),
#  ('#2-38_QVDP_Alopecie_Repousse', 37),
#  ('#7-58_Recidive', 14),
#  ('#7-52_Remission', 29),
#  ('#6-37_TRTEINS_TrtLymphodeme', 13),
#  ('#6-65_TRTEINS_Chirurgie', 35),
#  ('#2-123_QVDP_Sexualite_Prothese', 15),
#  ('#2-110_QVDP_Grossesse_Radiotherapie', 20),
#  ('Profile_write_age', 4),
#  ('#1-8_Menu_Traitement', 17),
#  ('#7-60_QVDA_Soins_Palliatifs', 4),
#  ('#2-72_QVDP_Fatigue_Sieste', 24),
#  ('Profile_read', 10),
#  ('intent', 1),
#  ('#9-13_Informations_metastase', 23),
#  ('#6-18_TRTEINS_Radiotherapie', 83),
#  ('#2-56_QVDP_DiminuerDouleur', 15),
#  ('#2-133_QVDP_RegimeAnticancer', 26),
#  ('Profile_update', 5),
#  ('#2-93_QVDP_Social_Proches', 18),
#  ('#2-126_QVDP_Sexualite_BaisseLibido', 30),
#  ('#2-59_QVDP_RadioT_Fatigue', 17),
#  ('#2-134_QVDP_Alimentation_Citron', 20),
#  ('#2-65_QVDP_Fatigue_Hormono', 17),
#  ('#2-37_QVDP_Alopecie_Quand', 37),
#  ('Profile_write_doseTraitement', 4),
#  ('#6-90_TRTEINS_Mauvais_Gout', 112),
#  ('#6-8_TRTEINS_Intrathecale', 12),
#  ('#2-101_QVDP_Social_RbProthese', 18),
#  ('#6-43_TRTEINS_PrixManchon', 11),
#  ('#2-128_QVDP_Sexualite_Couple', 50),
#  ('#2-120_QVDP_Sexualite', 60),
#  ('#2-90_QVDP_Fertilite_Ponction', 30),
#  ('#2-124_QVDP_Sexualite_PerteConfiance', 10),
#  ('#2-41_QVDP_Alopecie_Diminuer', 55),
#  ('#2-115_QVDP_Grossesse_Allaitement', 40),
#  ('#7-49_QVDA_Personne_de_confiance', 9),
#  ('#6-73_TRTEINS_Chirurgie_Curage_axillaire', 28),
#  ('#9-2_Informations_cancer', 90),
#  ('Profile_write_typeCancer', 1),
#  ('#2-79_QVDP_SportQuel', 31),
#  ('Conversation_rappel_update', 1),
#  ('Conversation_rappel_read', 32),
#  ('#6-33_TRTEINS_Lymphe', 15),
#  ('#6-23_TRTEINS_SeanceRadiotherapie', 11),
#  ('#6-91_TRTEINS_Ballonnement', 9),
#  ('#2-64-0_QVDP_Fatigue', 81),
#  ('#6-81_TRTEINS_Chirurgie_Mastectomie_risques', 7),
#  ('#2-109_QVDP_Grossesse_Chimiotherapie', 26),
#  ('#2-64_QVDP_Fatigue_Chimio', 14),
#  ('#2-48_QVDP_Alopecie_RbPerruque', 36),
#  ('#6-34_TRTEINS_Lymphoedeme', 54),
#  ('#2-45_QVDP_Alopecie_Perruque', 74),
#  ('#6-12_TRTEINS_ChimioAmbulatoire', 18),
#  ('#6-95_TRTEINS_Perte_Appetit', 43),
#  ('#6-92_TRTEINS_Diarrhee', 127),
#  ('#6-96_TRTEINS_Perte_Poids', 80),
#  ('#6-22_TRTEINS_EffetsecondairesRadiotherapie', 16),
#  ('#6-60_TRTEINS_PAC', 100),
#  ('#6-13_TRTEINS_PreparationChimio', 17),
#  ('#8-13_DDP_Secret_medical', 6),
#  ('#6-58_TRTEINS_Bouche_Seche', 63),
#  ('#6-83_TRTEINS_Prothese', 20),
#  ('#2-87_QVDP_Fertilite', 30),
#  ('#2-88_QVDP_Fertilite_Cycles', 6),
#  ('#2-102_QVDP_Social_RbPerruque', 16),
#  ('Conversation_rappel_update2', 18),
#  ('#6-24_TRTEINS_hormonotherapie', 69),
#  ('#6-39_TRTEINS_DrainageLymphodeme', 16),
#  ('#2-111_QVDP_Grossesse_Chirurgie', 18),
#  ('#2-112_QVDP_Grossesse_Hormonotherapie', 14),
#  ('#6-93_TRTEINS_Mauvaise_Haleine', 51),
#  ('#2-42_QVDP_Alopecie_Casque', 25),
#  ('Profile_write_rappels', 2),
#  ('Profile_write_partagerTemoignage', 1),
#  ('#2-85_QVDP_Fertilite_Preserver', 12),
#  ('#6-94_TRTEINS_Deglutition', 15),
#  ('conversation_rappel_rendezvous', 73)]

# %%
#on echantillonne pour avoir le même nbre de questions dans chaque categorie
for k in range (np.shape(CatCount)[0]):
    if (CatCount[k][1] < 193): #le plus quand nbre de question est 193
        DfCat = (data_train_clean.loc[data_train_clean['Intent']== CatCount[k][0],:]) #con recupere les dataframe avec l'intent souhaite
        nbreLigneManquant = 193 - CatCount[k][1] #on regarde combien il manque de question
        if nbreLigneManquant < np.shape(DfCat)[0]: #lorsque on doit prendre quelques colonnes on tire aleatoirement
            DfCatRand = DfCat.sample(n=nbreLigneManquant)
            data_train_clean = pd.concat([data_train_clean, DfCatRand], ignore_index=True)#on concatene avec l'ancien dataframe        
        else:
            taille = np.shape(DfCat)[0]
            DfCatTemp = DfCat.append([DfCat]*193,ignore_index=True) #on cree un dataframe des categories manquante assez gros pour pouvoirtirer aleatoirement les questions qu'on garde
            DfCatTemp = DfCatTemp.sample(n=nbreLigneManquant)
            data_train_clean = pd.concat([data_train_clean, DfCatTemp], ignore_index=True)
np.shape(data_train_clean)
# Out:
# (27985, 4)

# %%
CatCount= collections.Counter(data_train_clean['Intent']).items()
CatCount
# Out:
# [('#2-88_Reprise_Cycle', 193),
#  ('#2-135_QVDP_Alimentation_Alcool', 193),
#  ('#2-55_QVDP_Douleur', 193),
#  ('#5-37_Soutien_Psychologique', 193),
#  ('#2-97_QVDP_ResteACharge', 193),
#  ('#2-60_QVDP_RadioT_Diarrh\xc3\x83\xc2\xa9e', 193),
#  ('Profile_write_role', 193),
#  ('#1-5_Menu_Aidant', 193),
#  ('#6-41_TRTEINS_ManchonLymphodeme', 193),
#  ('#8-9_DDP_Charte_patient', 193),
#  ('#6-2_TRTEINS_Cycles', 193),
#  ('#6-35_TRTEINS_PrevenirLymphoedeme', 193),
#  ('#6-63_TRTEINS_PAC_Precautions', 193),
#  ('#2-125_QVDP_Sexualite_Reconstruction', 193),
#  ('#6-57_TRTEINS_Yeux_Secs', 193),
#  ('#6-44_TRTEINS_AllergieManchon', 193),
#  ('Profile_write_nomTraitement', 193),
#  ('#9-53_Informations_depistagesein', 193),
#  ('#2-122_QVDP_Sexualite_Alopecie', 193),
#  ('#2-58_QVDP_RadioT_Eff', 193),
#  ('#2-36_QVDP_Alopecie_Pourquoi', 193),
#  ('#6-5_TRTEINS_ChimioInjectable', 193),
#  ('#2-130_QVDP_Alimentation', 193),
#  ('#9-53_Depistage_cancer_sein', 193),
#  ('#2-75_QVDP_SportPrecautions', 193),
#  ('Conversation_Historique', 193),
#  ('#2-73_QVDP_Sport', 193),
#  ('#2-53_QVDP_Cils', 193),
#  ('#6-31_TRTEINS_Effetsecondaireshormonotherapie', 193),
#  ('#2-118_QVDP_Grossesse_Malformations', 193),
#  ('#8-11_DDP_Dossier_medical', 193),
#  ('#6-9_TRTEINS_ChimioIntraperitoneale', 193),
#  ('#2-107_QVDP_Grossesse', 193),
#  ('#6-67_TRTEINS_Chirurgie_Questions', 193),
#  ('#6-6_TRTEINS_ChimioOrale', 193),
#  ('#6-72_TRTEINS_Chirurgie_Cicatrice', 193),
#  ('#6-47_TRTEINS_InfectionManchon', 193),
#  ('Profile_write_recevoirTemoignage', 193),
#  ('#2-52_QVDP_Ongles', 193),
#  ('#001_Gestion_Abonnement', 193),
#  ('#2-106_QVDP_Social_HAD', 193),
#  ('#2-70_QVDP_Fatigue_Diminuer', 193),
#  ('#2-84_QVDP_Fertilite_GrossesseApresCancer', 193),
#  ('#6-73_TRTEINS_Chirurgie_Mastectomie', 193),
#  ('#6-53_TRTEINS_Aphtes', 193),
#  ('#8-8_DDP_Fin_de_vie', 193),
#  ('#2-96_QVDP_Social_Priseencharge', 193),
#  ('#2-137_QVDP_Alimentation_Remboursement', 193),
#  ('#2-100_QVDP_Social_Transports', 193),
#  ('#000_Menu_General', 193),
#  ('Profile_write_typeTraitement', 193),
#  ('#6-68_TRTEINS_Chirurgie_Anesthesie', 193),
#  ('#2-121_QVDP_Sexualite_Cicatrice', 193),
#  ('#6-40_TRTEINS_PressotherapieLymphodeme', 193),
#  ('#6-1_TRTEINS_Chimiotherapie', 193),
#  ('#2-47_QVDP_Alopecie_CoutPerruque', 193),
#  ('#8-6_DDP_Consentement_eclaire', 193),
#  ('#6-64_TRTEINS_PAC_Risques', 193),
#  ('#1-4_Menu_Patient_Recent', 193),
#  ('#9-20_Informations_Stades', 193),
#  ('#6-49_TRTEINS_Peau', 193),
#  ('#6-97_TRTEINS_Nausees_Vomissements', 193),
#  ('#2-49_QVDP_Alopecie_OuPerruque', 193),
#  ('#2-103_QVDP_Social_Banque', 193),
#  ('#2-61_QVDP_RadioT_Peau', 193),
#  ('#6-86_TRTEINS_Chirurgie_Reeducation', 193),
#  ('Profile_write_newsletter', 193),
#  ('#6-98_TRTEINS_EI_Frequents', 193),
#  ('#2-38_QVDP_Alopecie_Repousse', 193),
#  ('#7-58_Recidive', 193),
#  ('#7-52_Remission', 193),
#  ('#6-37_TRTEINS_TrtLymphodeme', 193),
#  ('#6-65_TRTEINS_Chirurgie', 193),
#  ('#2-123_QVDP_Sexualite_Prothese', 193),
#  ('#2-110_QVDP_Grossesse_Radiotherapie', 193),
#  ('Profile_write_age', 193),
#  ('#1-8_Menu_Traitement', 193),
#  ('#7-60_QVDA_Soins_Palliatifs', 193),
#  ('#2-72_QVDP_Fatigue_Sieste', 193),
#  ('Profile_read', 193),
#  ('intent', 193),
#  ('#9-13_Informations_metastase', 193),
#  ('#6-18_TRTEINS_Radiotherapie', 193),
#  ('#2-56_QVDP_DiminuerDouleur', 193),
#  ('#2-133_QVDP_RegimeAnticancer', 193),
#  ('Profile_update', 193),
#  ('#2-93_QVDP_Social_Proches', 193),
#  ('#2-126_QVDP_Sexualite_BaisseLibido', 193),
#  ('#2-59_QVDP_RadioT_Fatigue', 193),
#  ('#2-134_QVDP_Alimentation_Citron', 193),
#  ('#2-65_QVDP_Fatigue_Hormono', 193),
#  ('#2-37_QVDP_Alopecie_Quand', 193),
#  ('Profile_write_doseTraitement', 193),
#  ('#6-90_TRTEINS_Mauvais_Gout', 193),
#  ('#6-8_TRTEINS_Intrathecale', 193),
#  ('#2-101_QVDP_Social_RbProthese', 193),
#  ('#6-43_TRTEINS_PrixManchon', 193),
#  ('#2-128_QVDP_Sexualite_Couple', 193),
#  ('#2-120_QVDP_Sexualite', 193),
#  ('#2-90_QVDP_Fertilite_Ponction', 193),
#  ('#2-124_QVDP_Sexualite_PerteConfiance', 193),
#  ('#2-41_QVDP_Alopecie_Diminuer', 193),
#  ('#2-115_QVDP_Grossesse_Allaitement', 193),
#  ('#7-49_QVDA_Personne_de_confiance', 193),
#  ('#6-73_TRTEINS_Chirurgie_Curage_axillaire', 193),
#  ('#9-2_Informations_cancer', 193),
#  ('Profile_write_typeCancer', 193),
#  ('#2-79_QVDP_SportQuel', 193),
#  ('Conversation_rappel_update', 193),
#  ('Conversation_rappel_read', 193),
#  ('#6-33_TRTEINS_Lymphe', 193),
#  ('#6-23_TRTEINS_SeanceRadiotherapie', 193),
#  ('#6-91_TRTEINS_Ballonnement', 193),
#  ('#2-64-0_QVDP_Fatigue', 193),
#  ('#6-81_TRTEINS_Chirurgie_Mastectomie_risques', 193),
#  ('#2-109_QVDP_Grossesse_Chimiotherapie', 193),
#  ('#2-64_QVDP_Fatigue_Chimio', 193),
#  ('#2-48_QVDP_Alopecie_RbPerruque', 193),
#  ('#6-34_TRTEINS_Lymphoedeme', 193),
#  ('#2-45_QVDP_Alopecie_Perruque', 193),
#  ('#6-12_TRTEINS_ChimioAmbulatoire', 193),
#  ('#6-95_TRTEINS_Perte_Appetit', 193),
#  ('#6-92_TRTEINS_Diarrhee', 193),
#  ('#6-96_TRTEINS_Perte_Poids', 193),
#  ('#6-22_TRTEINS_EffetsecondairesRadiotherapie', 193),
#  ('#6-60_TRTEINS_PAC', 193),
#  ('#6-13_TRTEINS_PreparationChimio', 193),
#  ('#8-13_DDP_Secret_medical', 193),
#  ('#6-58_TRTEINS_Bouche_Seche', 193),
#  ('#6-83_TRTEINS_Prothese', 193),
#  ('#2-87_QVDP_Fertilite', 193),
#  ('#2-88_QVDP_Fertilite_Cycles', 193),
#  ('#2-102_QVDP_Social_RbPerruque', 193),
#  ('Conversation_rappel_update2', 193),
#  ('#6-24_TRTEINS_hormonotherapie', 193),
#  ('#6-39_TRTEINS_DrainageLymphodeme', 193),
#  ('#2-111_QVDP_Grossesse_Chirurgie', 193),
#  ('#2-112_QVDP_Grossesse_Hormonotherapie', 193),
#  ('#6-93_TRTEINS_Mauvaise_Haleine', 193),
#  ('#2-42_QVDP_Alopecie_Casque', 193),
#  ('Profile_write_rappels', 193),
#  ('Profile_write_partagerTemoignage', 193),
#  ('#2-85_QVDP_Fertilite_Preserver', 193),
#  ('#6-94_TRTEINS_Deglutition', 193),
#  ('conversation_rappel_rendezvous', 193)]

# %%
np.shape(data_train_clean)
# Out:
# (27985, 4)

# %%
#L5 = (data_train_clean.loc[data_train_clean['Intent']=='#8-9_DDP_Charte_patient',:])

# %%
data_train_clean
# Out:
#                                                 Question  \
# 0      seanc rayon etais enceint beb peut malform nai...
# 1                                              dos trait
# 2                                       pac chimiotherap
# 3                              effet taxol hormonotherap
# 4               diminu fatigu apre mastectom reconstruct
# 5                                    veux infos catheter
# 6                                chimiotherap ambulatoir
# 7                                         fertilit march
# 8                                obstruct chambr implant
# 9              soulag douleur suit trait pouvon fair cur
# 10                                      trait anti vomit
# 11                                  cout trait canc sein
# 12                                             pu halein
# 13      produit cosmet indiqu peau tel savon crem parfum
# 14                                       larm artificiel
# 15                          aliment preconis cas diarrhe
# 16                                   risqu perdr cheveux
# 17                 jai rend novembr echo doppl herceptin
# 18                                   don inform grossess
# 19                                       astuc arret vom
# 20                                         aphte repetit
# 21                           conseil nutrit remplac sucr
# 22                    temp apre seanc chimiotherap effet
# 23                             pass grossess radiotherap
# 24                             don infoym stimul ovarien
# 25                                   reconstruct mammair
# 26                                    peut achet perruqu
# 27                                              sexualit
# 28                                        peux pai trait
# 29                               fair amour alor cheveux
# ...                                                  ...
# 27955                                      rend septembr
# 27956                                               rend
# 27957                                        rend octobr
# 27958                                          rend mard
# 27959                                          rend mard
# 27960                                               rend
# 27961                                           met rend
# 27962                                               rend
# 27963                                      rend vou lund
# 27964                      fair pens rdv vendred novembr
# 27965                                           met rend
# 27966                                          rend mard
# 27967                                   rend apre demain
# 27968                       rappel aller medecin dimanch
# 27969                                          rend aout
# 27970                          rappel rend lieu septembr
# 27971                                        rend demain
# 27972                                          rend jeud
# 27973                      rend apre demain pourr rappel
# 27974                                   rend jeud octobr
# 27975                                   rend jeud octobr
# 27976                                          rend jeud
# 27977                                               rend
# 27978                          rappel rend lieu septembr
# 27979                                               rend
# 27980                                               rend
# 27981                                          rend lund
# 27982                                               rend
# 27983                                          rend lund
# 27984                                               aout
#
#                                      Intent                   BlockId  \
# 0       #2-118_QVDP_Grossesse_Malformations  598d7089e4b03f0d40c73834
# 1              Profile_write_doseTraitement  596340c2e4b0a226d0f53612
# 2                         #6-60_TRTEINS_PAC  59919288e4b0feb288a76cc3
# 3             #6-24_TRTEINS_hormonotherapie  59632c41e4b0a226d067cc6d
# 4                      #2-64-0_QVDP_Fatigue  59942265e4b068eebf52bb9f
# 5                         #6-60_TRTEINS_PAC  59919288e4b0feb288a76cc3
# 6                    #2-106_QVDP_Social_HAD  598b4541e4b03f0d36de29d9
# 7                      #2-87_QVDP_Fertilite  598b4175e4b03f0d36ca2350
# 8                 #6-64_TRTEINS_PAC_Risques  5991933de4b0feb288ac2399
# 9                #2-56_QVDP_DiminuerDouleur  59843d02e4b03f0d130d8199
# 10       #6-97_TRTEINS_Nausees_Vomissements  59955d76e4b032e0e7890bdf
# 11                  #2-97_QVDP_ResteACharge  598b43fbe4b03f0d36d746a7
# 12           #6-93_TRTEINS_Mauvaise_Haleine  5993f227e4b068eebe2d6550
# 13                       #6-49_TRTEINS_Peau  59918cf1e4b0feb28881fd9f
# 14                  #6-57_TRTEINS_Yeux_Secs  59918e4de4b0feb2888bc59e
# 15                   #6-92_TRTEINS_Diarrhee  5993f1d6e4b068eebe2bac82
# 16                #2-37_QVDP_Alopecie_Quand  5984342ae4b03f0d12ce91dc
# 17           conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 18                    #2-107_QVDP_Grossesse  598d6de3e4b03f0d40b7891f
# 19       #6-97_TRTEINS_Nausees_Vomissements  59955d76e4b032e0e7890bdf
# 20                     #6-53_TRTEINS_Aphtes  59918dbae4b0feb28887a14b
# 21                 #2-130_QVDP_Alimentation  5991c543e4b0b2045b0c568f
# 22              #6-1_TRTEINS_Chimiotherapie  59632c41e4b0a226d067c74f
# 23      #2-110_QVDP_Grossesse_Radiotherapie  598d6e96e4b03f0d40bbbd47
# 24            #2-90_QVDP_Fertilite_Ponction  598b4204e4b03f0d36cd3e60
# 25     #2-125_QVDP_Sexualite_Reconstruction  59918ad1e4b0feb288736b42
# 26           #2-49_QVDP_Alopecie_OuPerruque  598439eae4b03f0d12f637ea
# 27                    #2-120_QVDP_Sexualite  599188f4e4b0feb288676fca
# 28          #2-96_QVDP_Social_Priseencharge  598b43bee4b03f0d36d5f410
# 29           #2-122_QVDP_Sexualite_Alopecie  599189cae4b0feb2886cc2b0
# ...                                     ...                       ...
# 27955        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27956        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27957        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27958        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27959        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27960        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27961        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27962        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27963        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27964        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27965        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27966        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27967        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27968        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27969        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27970        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27971        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27972        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27973        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27974        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27975        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27976        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27977        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27978        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27979        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27980        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27981        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27982        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27983        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
# 27984        conversation_rappel_rendezvous  596340b8e4b0a226d0f4e811
#
#                                               Action
# 0                                        wiki_cancer
# 1      conversation_fichepatientwrite_dosetraitement
# 2                                        wiki_cancer
# 3                                        wiki_cancer
# 4                                        wiki_cancer
# 5                                        wiki_cancer
# 6                                        wiki_cancer
# 7                                        wiki_cancer
# 8                                        wiki_cancer
# 9                                        wiki_cancer
# 10                                       wiki_cancer
# 11                                       wiki_cancer
# 12                                       wiki_cancer
# 13                                       wiki_cancer
# 14                                       wiki_cancer
# 15                                       wiki_cancer
# 16                                       wiki_cancer
# 17                     conversation_rappelrendezvous
# 18                                       wiki_cancer
# 19                                       wiki_cancer
# 20                                       wiki_cancer
# 21                                       wiki_cancer
# 22                                       wiki_cancer
# 23                                       wiki_cancer
# 24                                       wiki_cancer
# 25                                       wiki_cancer
# 26                                       wiki_cancer
# 27                                       wiki_cancer
# 28                                       wiki_cancer
# 29                                       wiki_cancer
# ...                                              ...
# 27955                  conversation_rappelrendezvous
# 27956                  conversation_rappelrendezvous
# 27957                  conversation_rappelrendezvous
# 27958                  conversation_rappelrendezvous
# 27959                  conversation_rappelrendezvous
# 27960                  conversation_rappelrendezvous
# 27961                  conversation_rappelrendezvous
# 27962                  conversation_rappelrendezvous
# 27963                  conversation_rappelrendezvous
# 27964                  conversation_rappelrendezvous
# 27965                  conversation_rappelrendezvous
# 27966                  conversation_rappelrendezvous
# 27967                  conversation_rappelrendezvous
# 27968                  conversation_rappelrendezvous
# 27969                  conversation_rappelrendezvous
# 27970                  conversation_rappelrendezvous
# 27971                  conversation_rappelrendezvous
# 27972                  conversation_rappelrendezvous
# 27973                  conversation_rappelrendezvous
# 27974                  conversation_rappelrendezvous
# 27975                  conversation_rappelrendezvous
# 27976                  conversation_rappelrendezvous
# 27977                  conversation_rappelrendezvous
# 27978                  conversation_rappelrendezvous
# 27979                  conversation_rappelrendezvous
# 27980                  conversation_rappelrendezvous
# 27981                  conversation_rappelrendezvous
# 27982                  conversation_rappelrendezvous
# 27983                  conversation_rappelrendezvous
# 27984                  conversation_rappelrendezvous
#
# [27985 rows x 4 columns]

# %%
#ajout d'un data frame ayant 2 lignes dont l intent est Charte patient
L5 = (data_train_clean.loc[data_train_clean['Intent']=='#8-9_DDP_Charte_patient',:])
L2 = L5.sample(n=3)
AAA = pd.concat([data_train_clean, L2], ignore_index=True)

# %%
#ajout d'un data frame * 5 ayant 2 lignes dont l intent est Charte patient
#L5 = (data_train_clean.loc[data_train_clean['Intent']=='#8-9_DDP_Charte_patient',:])
#L2 = L5.sample(n=2)
#data_train_clean.append([L5]*5)

# %% [markdown]
# # Prediction

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer
from sklearn.feature_extraction import FeatureHasher

# %%
def vectorizer_train(df,column):
    col = df[column]
    # TFIDF
    vec = TfidfVectorizer(
            min_df = 1, #on prend tous les mots
            stop_words =stopwords,
            smooth_idf=True,
            norm='l2',
            sublinear_tf=True,
            use_idf=True, #tf avec idf
            ngram_range=(1,1)) 
    tfidf=vec.fit_transform(col)
    return vec,tfidf

def apply_vectorizer(df, vec, columns):
    
    data_hash = map(lambda x : " ".join(x), df[columns].values)  
    tfidf=vec.transform(df[columns])

    # TFIDF
    #tfidf=vec.transform(df)
    return tfidf

# %%
vec,X = vectorizer_train(data_train_clean,"Question")
Y = data_train_clean["Intent"].values
Xv = apply_vectorizer(data_valid_clean,vec,"Question")
Yv = data_valid_clean["Intent"].values

# %%
# Regression Logistique 
## estimation
from sklearn.linear_model import LogisticRegression
#si on augmente C, on augmente bcp le score
cla = LogisticRegression(penalty='l2', dual=False, tol=0.0001, C=1, fit_intercept=True,
                          intercept_scaling=1, class_weight=None, random_state=None, solver='liblinear',
                          max_iter=100, multi_class='ovr', verbose=0, warm_start=False, n_jobs=1)
cla.fit(X,Y)
score=cla.score(X,Y)
Y_predict = cla.predict(X)
                
print('# training score:',score)
# Out:
# ('# training score:', 0.96401643737716636)

# %%
## erreur en validation
scoreValidation=cla.score(Xv,Yv)
predict_v = cla.predict(Xv)
##probleme car tfidf et Xv pas le même nbre de colonne 
print('# validation score:',scoreValidation)
# Out:
# ('# validation score:', 0.69521912350597614)

# %% [markdown]
# Score d'apprentissage bien meilleur qu'avec les données brutes, mais le score de validation gagne que 2%
